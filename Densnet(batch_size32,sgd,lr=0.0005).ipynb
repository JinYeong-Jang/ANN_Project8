# %% [markdown]
# ### `Basic setting`

# %%
import sys

assert sys.version_info >= (3, 7)

from packaging import version
import sklearn
print("sklearn version: ", sklearn.__version__)
assert version.parse(sklearn.__version__) >= version.parse("1.0.1")

import tensorflow as tf
print("TF version: ", tf.__version__)
assert version.parse(tf.__version__) >= version.parse("2.8.0")

import matplotlib.pyplot as plt

# Is this notebook running on Colab or Kaggle?
IS_COLAB = "google.colab" in sys.modules
IS_KAGGLE = "kaggle_secrets" in sys.modules

if not tf.config.list_physical_devices('GPU'):
    print("No GPU was detected. Neural nets can be very slow without a GPU.")
    if IS_COLAB:
        print("Go to Runtime > Change runtime and select a GPU hardware "
              "accelerator.")
    if IS_KAGGLE:
        print("Go to Settings > Accelerator and select GPU.")


# To prevent "CUDNN_STATUS_ALLOC_FAILED" error with GPUs
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# sklearn version:  1.0.2
# TF version:  2.8.0
# 1 Physical GPUs, 1 Logical GPUs

# %%
import os
import time
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Flatten, Dense, Dropout, BatchNormalization, LeakyReLU, ReLU, ELU
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD
np.random.seed(42)

# %%
# check GPU
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 3870288466611567280
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 9879683072
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 12219577745856541808
#  physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6"
#  xla_global_id: 416903419]

# %% [markdown]
# ### `Load dataset (by_merge)`

# %%
# Hyper parameter setting
BATCH_SIZE = 32
EPOCHS = 100
VALIDATION_SPLIT = 0.15
LEARNING_RATE = 0.0005
PATIENCE = 10
MIN_LEARNING_RATE = 0.0001
DECAY_FACTOR = 0.2
DENSE_LAYER_ACTIVATION = 'elu'
FINAL_LAYER_ACTIVATION = 'softmax'
LOSS_FUNCTION = 'categorical_crossentropy'
METRICS = ['accuracy']
optimizer = SGD(learning_rate=LEARNING_RATE)

CHECK_POINT_BALANCE = 'Best_points_densenet.h'

# %% [markdown]
# ### `Load dataset (by_balanced)`

# %%
# 데이터 불러오기
testing_set_balance = pd.read_csv('emnist-balanced-test.csv')
training_set_balance = pd.read_csv('emnist-balanced-train.csv')


# 훈련 데이터와 레이블 추출
train_y_balance = np.array(training_set_balance.iloc[:, 0].values)
train_x_balance = np.array(training_set_balance.iloc[:, 1:].values)

# 테스트 데이터와 레이블 추출
test_y_balance = np.array(testing_set_balance.iloc[:, 0].values)
test_x_balance = np.array(testing_set_balance.iloc[:, 1:].values)

# 데이터 정규화
train_x_balance = train_x_balance / 255.0
test_x_balance = test_x_balance / 255.0

# 이미지 크기 재조정 (데이터 차원 변경)
images_height = 28
images_width = 28
train_x_balance = train_x_balance.reshape(train_x_balance.shape[0], images_height, images_width, 1)
test_x_balance = test_x_balance.reshape(test_x_balance.shape[0], images_height, images_width, 1)

# 클래스 수 = 47
number_of_classes = 47

# 레이블 원-핫 인코딩
train_y_balance = tf.keras.utils.to_categorical(train_y_balance, number_of_classes)
test_y_balance = tf.keras.utils.to_categorical(test_y_balance, number_of_classes)

#VALIDATION_SPLIT = 0.15
train_x_balance, val_x_balance, train_y_balance, val_y_balance = train_test_split(train_x_balance, train_y_balance, 
                                                                              test_size=VALIDATION_SPLIT, random_state=42)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau,ModelCheckpoint
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Conv2D, Input,MaxPooling2D, Dense, Flatten ,Activation ,  BatchNormalization , Dropout ,AveragePooling2D
from tensorflow.keras.models import Model
from functools import partial

# %% [markdown]
# #### Training PersonalModelwith bybalanced dataset

# %%
# Define Densenet
model = tf.keras.Sequential([
    Conv2D(16, kernel_size=(5, 5), activation=DENSE_LAYER_ACTIVATION, input_shape=(28, 28, 1), padding='same'),
    AveragePooling2D(),
    # Conv2D(16, kernel_size=(3, 3), activation=DENSE_LAYER_ACTIVATION, padding='same'),
    # BatchNormalization(),
    # AveragePooling2D(),
    Conv2D(32, kernel_size=(5, 5), activation=DENSE_LAYER_ACTIVATION, padding='same'),
    BatchNormalization(),
    AveragePooling2D(),
    Conv2D(64, kernel_size=(5, 5), activation=DENSE_LAYER_ACTIVATION, padding='same'),
    BatchNormalization(),
    AveragePooling2D(),
    Conv2D(128, kernel_size=(5, 5), activation=DENSE_LAYER_ACTIVATION, padding='same'),
    BatchNormalization(),
    AveragePooling2D(pool_size=(1, 1)),
    Flatten(),
    Dense(128, activation=DENSE_LAYER_ACTIVATION),
    Dropout(0.5),
    Dense(number_of_classes, activation=FINAL_LAYER_ACTIVATION)
])

#model.summary()

# %%
# 모델 컴파일
#LOSS_FUNCTION = 'categorical_crossentropy'
#LEARNING_RATE = 0.001
#METRICS = ['accuracy']

model.compile(optimizer=optimizer,
            loss=LOSS_FUNCTION,
            metrics=METRICS)

# 콜백 설정
#DECAY_FACTOR = 0.2
#PATIENCE = 3
#MIN_LEARNING_RATE = 0.0001

callbacks_balance = [
    ModelCheckpoint(CHECK_POINT_BALANCE, verbose=1, save_best_only=True, monitor='val_accuracy', mode='max'),
    EarlyStopping(monitor='val_accuracy', restore_best_weights=True, patience=PATIENCE, mode='max'),
    ReduceLROnPlateau(monitor='val_loss', patience=PATIENCE, factor=DECAY_FACTOR, min_lr=MIN_LEARNING_RATE)
]

# %%
start_time = time.time()  # 학습 시작 시간

# 모델 학습
history_balance = model.fit(train_x_balance, train_y_balance, batch_size=BATCH_SIZE, epochs=EPOCHS, 
                                validation_data=(val_x_balance, val_y_balance), callbacks=callbacks_balance)

training_time = time.time() - start_time
# Out:
# Epoch 1/100
# 2997/2997 [==============================] - ETA: 0s - loss: 2.1057 - accuracy: 0.4241
# Epoch 1: val_accuracy improved from -inf to 0.63712, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 8s 3ms/step - loss: 2.1057 - accuracy: 0.4241 - val_loss: 1.3877 - val_accuracy: 0.6371 - lr: 5.0000e-04
# Epoch 2/100
# 2977/2997 [============================>.] - ETA: 0s - loss: 1.6048 - accuracy: 0.5509
# Epoch 2: val_accuracy improved from 0.63712 to 0.70077, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 1.6036 - accuracy: 0.5512 - val_loss: 1.0860 - val_accuracy: 0.7008 - lr: 5.0000e-04
# Epoch 3/100
# 2985/2997 [============================>.] - ETA: 0s - loss: 1.3253 - accuracy: 0.6197
# Epoch 3: val_accuracy improved from 0.70077 to 0.73948, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 1.3249 - accuracy: 0.6199 - val_loss: 0.9064 - val_accuracy: 0.7395 - lr: 5.0000e-04
# Epoch 4/100
# 2980/2997 [============================>.] - ETA: 0s - loss: 1.1408 - accuracy: 0.6659
# Epoch 4: val_accuracy improved from 0.73948 to 0.76755, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 1.1400 - accuracy: 0.6659 - val_loss: 0.7817 - val_accuracy: 0.7676 - lr: 5.0000e-04
# Epoch 5/100
# 2972/2997 [============================>.] - ETA: 0s - loss: 1.0120 - accuracy: 0.6983
# Epoch 5: val_accuracy improved from 0.76755 to 0.77470, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 1.0112 - accuracy: 0.6985 - val_loss: 0.7323 - val_accuracy: 0.7747 - lr: 5.0000e-04
# Epoch 6/100
# 2978/2997 [============================>.] - ETA: 0s - loss: 0.9258 - accuracy: 0.7210
# Epoch 6: val_accuracy improved from 0.77470 to 0.79249, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.9258 - accuracy: 0.7209 - val_loss: 0.6707 - val_accuracy: 0.7925 - lr: 5.0000e-04
# Epoch 7/100
# 2980/2997 [============================>.] - ETA: 0s - loss: 0.8609 - accuracy: 0.7374
# Epoch 7: val_accuracy improved from 0.79249 to 0.80656, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 8s 3ms/step - loss: 0.8605 - accuracy: 0.7376 - val_loss: 0.6160 - val_accuracy: 0.8066 - lr: 5.0000e-04
# Epoch 8/100
# 2992/2997 [============================>.] - ETA: 0s - loss: 0.8112 - accuracy: 0.7516
# Epoch 8: val_accuracy improved from 0.80656 to 0.81259, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 8s 3ms/step - loss: 0.8109 - accuracy: 0.7516 - val_loss: 0.5884 - val_accuracy: 0.8126 - lr: 5.0000e-04
# Epoch 9/100
# 2971/2997 [============================>.] - ETA: 0s - loss: 0.7704 - accuracy: 0.7619
# Epoch 9: val_accuracy improved from 0.81259 to 0.81596, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 8s 3ms/step - loss: 0.7702 - accuracy: 0.7619 - val_loss: 0.5659 - val_accuracy: 0.8160 - lr: 5.0000e-04
# Epoch 10/100
# 2990/2997 [============================>.] - ETA: 0s - loss: 0.7339 - accuracy: 0.7707
# Epoch 10: val_accuracy improved from 0.81596 to 0.81939, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.7339 - accuracy: 0.7707 - val_loss: 0.5652 - val_accuracy: 0.8194 - lr: 5.0000e-04
# Epoch 11/100
# 2990/2997 [============================>.] - ETA: 0s - loss: 0.7061 - accuracy: 0.7794
# Epoch 11: val_accuracy improved from 0.81939 to 0.82796, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.7062 - accuracy: 0.7794 - val_loss: 0.5261 - val_accuracy: 0.8280 - lr: 5.0000e-04
# Epoch 12/100
# 2976/2997 [============================>.] - ETA: 0s - loss: 0.6819 - accuracy: 0.7844
# Epoch 12: val_accuracy improved from 0.82796 to 0.83138, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.6815 - accuracy: 0.7845 - val_loss: 0.5021 - val_accuracy: 0.8314 - lr: 5.0000e-04
# Epoch 13/100
# 2980/2997 [============================>.] - ETA: 0s - loss: 0.6575 - accuracy: 0.7910
# Epoch 13: val_accuracy did not improve from 0.83138
# 2997/2997 [==============================] - 6s 2ms/step - loss: 0.6578 - accuracy: 0.7909 - val_loss: 0.5035 - val_accuracy: 0.8305 - lr: 5.0000e-04
# Epoch 14/100
# 2979/2997 [============================>.] - ETA: 0s - loss: 0.6432 - accuracy: 0.7955
# Epoch 14: val_accuracy improved from 0.83138 to 0.83995, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.6429 - accuracy: 0.7956 - val_loss: 0.4774 - val_accuracy: 0.8400 - lr: 5.0000e-04
# Epoch 15/100
# 2986/2997 [============================>.] - ETA: 0s - loss: 0.6249 - accuracy: 0.8008
# Epoch 15: val_accuracy improved from 0.83995 to 0.84137, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.6250 - accuracy: 0.8008 - val_loss: 0.4708 - val_accuracy: 0.8414 - lr: 5.0000e-04
# Epoch 16/100
# 2989/2997 [============================>.] - ETA: 0s - loss: 0.6069 - accuracy: 0.8045
# Epoch 16: val_accuracy improved from 0.84137 to 0.84758, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 8s 3ms/step - loss: 0.6070 - accuracy: 0.8045 - val_loss: 0.4535 - val_accuracy: 0.8476 - lr: 5.0000e-04
# Epoch 17/100
# 2976/2997 [============================>.] - ETA: 0s - loss: 0.5932 - accuracy: 0.8095
# Epoch 17: val_accuracy improved from 0.84758 to 0.84835, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5937 - accuracy: 0.8093 - val_loss: 0.4478 - val_accuracy: 0.8483 - lr: 5.0000e-04
# Epoch 18/100
# 2997/2997 [==============================] - ETA: 0s - loss: 0.5809 - accuracy: 0.8124
# Epoch 18: val_accuracy did not improve from 0.84835
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5809 - accuracy: 0.8124 - val_loss: 0.4804 - val_accuracy: 0.8377 - lr: 5.0000e-04
# Epoch 19/100
# 2988/2997 [============================>.] - ETA: 0s - loss: 0.5697 - accuracy: 0.8161
# Epoch 19: val_accuracy did not improve from 0.84835
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5698 - accuracy: 0.8161 - val_loss: 0.4402 - val_accuracy: 0.8478 - lr: 5.0000e-04
# Epoch 20/100
# 2993/2997 [============================>.] - ETA: 0s - loss: 0.5621 - accuracy: 0.8170
# Epoch 20: val_accuracy improved from 0.84835 to 0.85059, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5621 - accuracy: 0.8170 - val_loss: 0.4398 - val_accuracy: 0.8506 - lr: 5.0000e-04
# Epoch 21/100
# 2966/2997 [============================>.] - ETA: 0s - loss: 0.5530 - accuracy: 0.8203
# Epoch 21: val_accuracy did not improve from 0.85059
# 2997/2997 [==============================] - 6s 2ms/step - loss: 0.5533 - accuracy: 0.8202 - val_loss: 0.4408 - val_accuracy: 0.8477 - lr: 5.0000e-04
# Epoch 22/100
# 2974/2997 [============================>.] - ETA: 0s - loss: 0.5421 - accuracy: 0.8226
# Epoch 22: val_accuracy improved from 0.85059 to 0.85355, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5418 - accuracy: 0.8228 - val_loss: 0.4218 - val_accuracy: 0.8535 - lr: 5.0000e-04
# Epoch 23/100
# 2996/2997 [============================>.] - ETA: 0s - loss: 0.5315 - accuracy: 0.8250
# Epoch 23: val_accuracy improved from 0.85355 to 0.85496, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5315 - accuracy: 0.8250 - val_loss: 0.4215 - val_accuracy: 0.8550 - lr: 5.0000e-04
# Epoch 24/100
# 2991/2997 [============================>.] - ETA: 0s - loss: 0.5289 - accuracy: 0.8274
# Epoch 24: val_accuracy improved from 0.85496 to 0.85585, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5289 - accuracy: 0.8274 - val_loss: 0.4192 - val_accuracy: 0.8559 - lr: 5.0000e-04
# Epoch 25/100
# 2985/2997 [============================>.] - ETA: 0s - loss: 0.5159 - accuracy: 0.8303
# Epoch 25: val_accuracy improved from 0.85585 to 0.85792, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5162 - accuracy: 0.8301 - val_loss: 0.4107 - val_accuracy: 0.8579 - lr: 5.0000e-04
# Epoch 26/100
# 2983/2997 [============================>.] - ETA: 0s - loss: 0.5075 - accuracy: 0.8329
# Epoch 26: val_accuracy improved from 0.85792 to 0.85804, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5077 - accuracy: 0.8328 - val_loss: 0.4026 - val_accuracy: 0.8580 - lr: 5.0000e-04
# Epoch 27/100
# 2975/2997 [============================>.] - ETA: 0s - loss: 0.5001 - accuracy: 0.8349
# Epoch 27: val_accuracy improved from 0.85804 to 0.86277, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5000 - accuracy: 0.8349 - val_loss: 0.3932 - val_accuracy: 0.8628 - lr: 5.0000e-04
# Epoch 28/100
# 2976/2997 [============================>.] - ETA: 0s - loss: 0.4985 - accuracy: 0.8354
# Epoch 28: val_accuracy did not improve from 0.86277
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.4984 - accuracy: 0.8356 - val_loss: 0.4071 - val_accuracy: 0.8568 - lr: 5.0000e-04
# Epoch 29/100
# 2987/2997 [============================>.] - ETA: 0s - loss: 0.4928 - accuracy: 0.8369
# Epoch 29: val_accuracy did not improve from 0.86277
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.4928 - accuracy: 0.8369 - val_loss: 0.4055 - val_accuracy: 0.8589 - lr: 5.0000e-04
# Epoch 30/100
# 2978/2997 [============================>.] - ETA: 0s - loss: 0.4856 - accuracy: 0.8378
# Epoch 30: val_accuracy did not improve from 0.86277
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.4853 - accuracy: 0.8380 - val_loss: 0.3918 - val_accuracy: 0.8627 - lr: 5.0000e-04
# Epoch 31/100
# 2979/2997 [============================>.] - ETA: 0s - loss: 0.4821 - accuracy: 0.8399
# Epoch 31: val_accuracy did not improve from 0.86277
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.4823 - accuracy: 0.8399 - val_loss: 0.3871 - val_accuracy: 0.8622 - lr: 5.0000e-04
# Epoch 32/100
# 2985/2997 [============================>.] - ETA: 0s - loss: 0.4790 - accuracy: 0.8407
# Epoch 32: val_accuracy did not improve from 0.86277
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.4794 - accuracy: 0.8406 - val_loss: 0.3915 - val_accuracy: 0.8620 - lr: 5.0000e-04
# Epoch 33/100
# 2981/2997 [============================>.] - ETA: 0s - loss: 0.4708 - accuracy: 0.8448
# Epoch 33: val_accuracy improved from 0.86277 to 0.86702, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.4706 - accuracy: 0.8449 - val_loss: 0.3777 - val_accuracy: 0.8670 - lr: 5.0000e-04
# Epoch 34/100
# 2973/2997 [============================>.] - ETA: 0s - loss: 0.4674 - accuracy: 0.8458
# Epoch 34: val_accuracy did not improve from 0.86702
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.4670 - accuracy: 0.8460 - val_loss: 0.3774 - val_accuracy: 0.8664 - lr: 5.0000e-04
# Epoch 35/100
# 2997/2997 [==============================] - ETA: 0s - loss: 0.4614 - accuracy: 0.8475
# Epoch 35: val_accuracy did not improve from 0.86702
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.4614 - accuracy: 0.8475 - val_loss: 0.3853 - val_accuracy: 0.8634 - lr: 5.0000e-04
# Epoch 36/100
# 2988/2997 [============================>.] - ETA: 0s - loss: 0.4583 - accuracy: 0.8460
# Epoch 36: val_accuracy improved from 0.86702 to 0.86726, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 8s 3ms/step - loss: 0.4585 - accuracy: 0.8460 - val_loss: 0.3758 - val_accuracy: 0.8673 - lr: 5.0000e-04
# Epoch 37/100
# 2968/2997 [============================>.] - ETA: 0s - loss: 0.4580 - accuracy: 0.8460
# Epoch 37: val_accuracy improved from 0.86726 to 0.86738, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.4576 - accuracy: 0.8461 - val_loss: 0.3777 - val_accuracy: 0.8674 - lr: 5.0000e-04
# Epoch 38/100
# 2979/2997 [============================>.] - ETA: 0s - loss: 0.4495 - accuracy: 0.8498
# Epoch 38: val_accuracy improved from 0.86738 to 0.86785, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.4492 - accuracy: 0.8500 - val_loss: 0.3704 - val_accuracy: 0.8678 - lr: 5.0000e-04
# Epoch 39/100
# 2979/2997 [============================>.] - ETA: 0s - loss: 0.4467 - accuracy: 0.8482
# Epoch 39: val_accuracy improved from 0.86785 to 0.86803, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.4464 - accuracy: 0.8483 - val_loss: 0.3700 - val_accuracy: 0.8680 - lr: 5.0000e-04
# Epoch 40/100
# 2971/2997 [============================>.] - ETA: 0s - loss: 0.4420 - accuracy: 0.8515
# Epoch 40: val_accuracy did not improve from 0.86803
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.4421 - accuracy: 0.8515 - val_loss: 0.3726 - val_accuracy: 0.8659 - lr: 5.0000e-04
# Epoch 41/100
# 2989/2997 [============================>.] - ETA: 0s - loss: 0.4387 - accuracy: 0.8529
# Epoch 41: val_accuracy improved from 0.86803 to 0.87175, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.4387 - accuracy: 0.8530 - val_loss: 0.3618 - val_accuracy: 0.8717 - lr: 5.0000e-04
# Epoch 42/100
# 2979/2997 [============================>.] - ETA: 0s - loss: 0.4379 - accuracy: 0.8513
# Epoch 42: val_accuracy did not improve from 0.87175
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.4378 - accuracy: 0.8514 - val_loss: 0.3699 - val_accuracy: 0.8686 - lr: 5.0000e-04
# Epoch 43/100
# 2986/2997 [============================>.] - ETA: 0s - loss: 0.4349 - accuracy: 0.8532
# Epoch 43: val_accuracy improved from 0.87175 to 0.87204, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.4346 - accuracy: 0.8532 - val_loss: 0.3606 - val_accuracy: 0.8720 - lr: 5.0000e-04
# Epoch 44/100
# 2981/2997 [============================>.] - ETA: 0s - loss: 0.4298 - accuracy: 0.8557
# Epoch 44: val_accuracy did not improve from 0.87204
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.4299 - accuracy: 0.8558 - val_loss: 0.3643 - val_accuracy: 0.8687 - lr: 5.0000e-04
# Epoch 45/100
# 2970/2997 [============================>.] - ETA: 0s - loss: 0.4294 - accuracy: 0.8539
# Epoch 45: val_accuracy did not improve from 0.87204
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.4289 - accuracy: 0.8541 - val_loss: 0.3593 - val_accuracy: 0.8716 - lr: 5.0000e-04
# Epoch 46/100
# 2972/2997 [============================>.] - ETA: 0s - loss: 0.4248 - accuracy: 0.8555
# Epoch 46: val_accuracy improved from 0.87204 to 0.87329, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 8s 3ms/step - loss: 0.4246 - accuracy: 0.8556 - val_loss: 0.3582 - val_accuracy: 0.8733 - lr: 5.0000e-04
# Epoch 47/100
# 2990/2997 [============================>.] - ETA: 0s - loss: 0.4187 - accuracy: 0.8580
# Epoch 47: val_accuracy improved from 0.87329 to 0.87340, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.4188 - accuracy: 0.8580 - val_loss: 0.3575 - val_accuracy: 0.8734 - lr: 5.0000e-04
# Epoch 48/100
# 2977/2997 [============================>.] - ETA: 0s - loss: 0.4190 - accuracy: 0.8581
# Epoch 48: val_accuracy improved from 0.87340 to 0.87352, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 8s 3ms/step - loss: 0.4189 - accuracy: 0.8581 - val_loss: 0.3569 - val_accuracy: 0.8735 - lr: 5.0000e-04
# Epoch 49/100
# 2985/2997 [============================>.] - ETA: 0s - loss: 0.4164 - accuracy: 0.8585
# Epoch 49: val_accuracy did not improve from 0.87352
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.4162 - accuracy: 0.8586 - val_loss: 0.3581 - val_accuracy: 0.8716 - lr: 5.0000e-04
# Epoch 50/100
# 2973/2997 [============================>.] - ETA: 0s - loss: 0.4128 - accuracy: 0.8593
# Epoch 50: val_accuracy improved from 0.87352 to 0.87388, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 8s 3ms/step - loss: 0.4123 - accuracy: 0.8593 - val_loss: 0.3527 - val_accuracy: 0.8739 - lr: 5.0000e-04
# Epoch 51/100
# 2996/2997 [============================>.] - ETA: 0s - loss: 0.4109 - accuracy: 0.8598
# Epoch 51: val_accuracy did not improve from 0.87388
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.4109 - accuracy: 0.8598 - val_loss: 0.3567 - val_accuracy: 0.8722 - lr: 5.0000e-04
# Epoch 52/100
# 2969/2997 [============================>.] - ETA: 0s - loss: 0.4083 - accuracy: 0.8608
# Epoch 52: val_accuracy improved from 0.87388 to 0.87837, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 8s 3ms/step - loss: 0.4087 - accuracy: 0.8607 - val_loss: 0.3454 - val_accuracy: 0.8784 - lr: 5.0000e-04
# Epoch 53/100
# 2977/2997 [============================>.] - ETA: 0s - loss: 0.4059 - accuracy: 0.8618
# Epoch 53: val_accuracy did not improve from 0.87837
# 2997/2997 [==============================] - 8s 3ms/step - loss: 0.4059 - accuracy: 0.8618 - val_loss: 0.3510 - val_accuracy: 0.8745 - lr: 5.0000e-04
# Epoch 54/100
# 2986/2997 [============================>.] - ETA: 0s - loss: 0.4050 - accuracy: 0.8618
# Epoch 54: val_accuracy did not improve from 0.87837
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.4053 - accuracy: 0.8618 - val_loss: 0.3521 - val_accuracy: 0.8729 - lr: 5.0000e-04
# Epoch 55/100
# 2981/2997 [============================>.] - ETA: 0s - loss: 0.4000 - accuracy: 0.8627
# Epoch 55: val_accuracy did not improve from 0.87837
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.4001 - accuracy: 0.8627 - val_loss: 0.3513 - val_accuracy: 0.8739 - lr: 5.0000e-04
# Epoch 56/100
# 2990/2997 [============================>.] - ETA: 0s - loss: 0.3996 - accuracy: 0.8638
# Epoch 56: val_accuracy did not improve from 0.87837
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3996 - accuracy: 0.8637 - val_loss: 0.3461 - val_accuracy: 0.8763 - lr: 5.0000e-04
# Epoch 57/100
# 2983/2997 [============================>.] - ETA: 0s - loss: 0.3969 - accuracy: 0.8647
# Epoch 57: val_accuracy did not improve from 0.87837
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3967 - accuracy: 0.8647 - val_loss: 0.3436 - val_accuracy: 0.8765 - lr: 5.0000e-04
# Epoch 58/100
# 2984/2997 [============================>.] - ETA: 0s - loss: 0.3942 - accuracy: 0.8647
# Epoch 58: val_accuracy did not improve from 0.87837
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3939 - accuracy: 0.8649 - val_loss: 0.3434 - val_accuracy: 0.8766 - lr: 5.0000e-04
# Epoch 59/100
# 2993/2997 [============================>.] - ETA: 0s - loss: 0.3919 - accuracy: 0.8659
# Epoch 59: val_accuracy did not improve from 0.87837
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3919 - accuracy: 0.8659 - val_loss: 0.3557 - val_accuracy: 0.8715 - lr: 5.0000e-04
# Epoch 60/100
# 2992/2997 [============================>.] - ETA: 0s - loss: 0.3895 - accuracy: 0.8669
# Epoch 60: val_accuracy did not improve from 0.87837
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3896 - accuracy: 0.8668 - val_loss: 0.3447 - val_accuracy: 0.8743 - lr: 5.0000e-04
# Epoch 61/100
# 2996/2997 [============================>.] - ETA: 0s - loss: 0.3870 - accuracy: 0.8680
# Epoch 61: val_accuracy did not improve from 0.87837
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3870 - accuracy: 0.8680 - val_loss: 0.3435 - val_accuracy: 0.8755 - lr: 5.0000e-04
# Epoch 62/100
# 2972/2997 [============================>.] - ETA: 0s - loss: 0.3854 - accuracy: 0.8668
# Epoch 62: val_accuracy improved from 0.87837 to 0.87961, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3855 - accuracy: 0.8668 - val_loss: 0.3383 - val_accuracy: 0.8796 - lr: 5.0000e-04
# Epoch 63/100
# 2966/2997 [============================>.] - ETA: 0s - loss: 0.3856 - accuracy: 0.8669
# Epoch 63: val_accuracy did not improve from 0.87961
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3858 - accuracy: 0.8669 - val_loss: 0.3497 - val_accuracy: 0.8753 - lr: 5.0000e-04
# Epoch 64/100
# 2986/2997 [============================>.] - ETA: 0s - loss: 0.3812 - accuracy: 0.8679
# Epoch 64: val_accuracy did not improve from 0.87961
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3810 - accuracy: 0.8679 - val_loss: 0.3381 - val_accuracy: 0.8792 - lr: 5.0000e-04
# Epoch 65/100
# 2981/2997 [============================>.] - ETA: 0s - loss: 0.3786 - accuracy: 0.8692
# Epoch 65: val_accuracy did not improve from 0.87961
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3784 - accuracy: 0.8692 - val_loss: 0.3366 - val_accuracy: 0.8755 - lr: 5.0000e-04
# Epoch 66/100
# 2988/2997 [============================>.] - ETA: 0s - loss: 0.3789 - accuracy: 0.8688
# Epoch 66: val_accuracy did not improve from 0.87961
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3789 - accuracy: 0.8687 - val_loss: 0.3392 - val_accuracy: 0.8764 - lr: 5.0000e-04
# Epoch 67/100
# 2986/2997 [============================>.] - ETA: 0s - loss: 0.3775 - accuracy: 0.8693
# Epoch 67: val_accuracy improved from 0.87961 to 0.88174, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3773 - accuracy: 0.8693 - val_loss: 0.3272 - val_accuracy: 0.8817 - lr: 5.0000e-04
# Epoch 68/100
# 2975/2997 [============================>.] - ETA: 0s - loss: 0.3772 - accuracy: 0.8690
# Epoch 68: val_accuracy did not improve from 0.88174
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3768 - accuracy: 0.8692 - val_loss: 0.3334 - val_accuracy: 0.8795 - lr: 5.0000e-04
# Epoch 69/100
# 2989/2997 [============================>.] - ETA: 0s - loss: 0.3757 - accuracy: 0.8696
# Epoch 69: val_accuracy did not improve from 0.88174
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3757 - accuracy: 0.8695 - val_loss: 0.3296 - val_accuracy: 0.8810 - lr: 5.0000e-04
# Epoch 70/100
# 2982/2997 [============================>.] - ETA: 0s - loss: 0.3728 - accuracy: 0.8708
# Epoch 70: val_accuracy improved from 0.88174 to 0.88221, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 8s 3ms/step - loss: 0.3727 - accuracy: 0.8708 - val_loss: 0.3295 - val_accuracy: 0.8822 - lr: 5.0000e-04
# Epoch 71/100
# 2990/2997 [============================>.] - ETA: 0s - loss: 0.3706 - accuracy: 0.8719
# Epoch 71: val_accuracy did not improve from 0.88221
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3705 - accuracy: 0.8720 - val_loss: 0.3358 - val_accuracy: 0.8796 - lr: 5.0000e-04
# Epoch 72/100
# 2997/2997 [==============================] - ETA: 0s - loss: 0.3690 - accuracy: 0.8721
# Epoch 72: val_accuracy did not improve from 0.88221
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3690 - accuracy: 0.8721 - val_loss: 0.3281 - val_accuracy: 0.8820 - lr: 5.0000e-04
# Epoch 73/100
# 2969/2997 [============================>.] - ETA: 0s - loss: 0.3684 - accuracy: 0.8730
# Epoch 73: val_accuracy did not improve from 0.88221
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3680 - accuracy: 0.8731 - val_loss: 0.3408 - val_accuracy: 0.8784 - lr: 5.0000e-04
# Epoch 74/100
# 2993/2997 [============================>.] - ETA: 0s - loss: 0.3658 - accuracy: 0.8729
# Epoch 74: val_accuracy did not improve from 0.88221
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3661 - accuracy: 0.8728 - val_loss: 0.3564 - val_accuracy: 0.8710 - lr: 5.0000e-04
# Epoch 75/100
# 2969/2997 [============================>.] - ETA: 0s - loss: 0.3652 - accuracy: 0.8731
# Epoch 75: val_accuracy did not improve from 0.88221
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3650 - accuracy: 0.8732 - val_loss: 0.3453 - val_accuracy: 0.8741 - lr: 5.0000e-04
# Epoch 76/100
# 2983/2997 [============================>.] - ETA: 0s - loss: 0.3645 - accuracy: 0.8729
# Epoch 76: val_accuracy improved from 0.88221 to 0.88298, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 8s 3ms/step - loss: 0.3644 - accuracy: 0.8728 - val_loss: 0.3231 - val_accuracy: 0.8830 - lr: 5.0000e-04
# Epoch 77/100
# 2985/2997 [============================>.] - ETA: 0s - loss: 0.3622 - accuracy: 0.8751
# Epoch 77: val_accuracy did not improve from 0.88298
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3621 - accuracy: 0.8751 - val_loss: 0.3370 - val_accuracy: 0.8766 - lr: 5.0000e-04
# Epoch 78/100
# 2986/2997 [============================>.] - ETA: 0s - loss: 0.3597 - accuracy: 0.8745
# Epoch 78: val_accuracy did not improve from 0.88298
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3595 - accuracy: 0.8746 - val_loss: 0.3274 - val_accuracy: 0.8793 - lr: 5.0000e-04
# Epoch 79/100
# 2982/2997 [============================>.] - ETA: 0s - loss: 0.3579 - accuracy: 0.8753
# Epoch 79: val_accuracy improved from 0.88298 to 0.88363, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 8s 3ms/step - loss: 0.3585 - accuracy: 0.8752 - val_loss: 0.3183 - val_accuracy: 0.8836 - lr: 5.0000e-04
# Epoch 80/100
# 2977/2997 [============================>.] - ETA: 0s - loss: 0.3580 - accuracy: 0.8755
# Epoch 80: val_accuracy did not improve from 0.88363
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3582 - accuracy: 0.8755 - val_loss: 0.3277 - val_accuracy: 0.8795 - lr: 5.0000e-04
# Epoch 81/100
# 2974/2997 [============================>.] - ETA: 0s - loss: 0.3573 - accuracy: 0.8748
# Epoch 81: val_accuracy did not improve from 0.88363
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3574 - accuracy: 0.8749 - val_loss: 0.3191 - val_accuracy: 0.8830 - lr: 5.0000e-04
# Epoch 82/100
# 2992/2997 [============================>.] - ETA: 0s - loss: 0.3548 - accuracy: 0.8756
# Epoch 82: val_accuracy did not improve from 0.88363
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3547 - accuracy: 0.8756 - val_loss: 0.3204 - val_accuracy: 0.8833 - lr: 5.0000e-04
# Epoch 83/100
# 2997/2997 [==============================] - ETA: 0s - loss: 0.3545 - accuracy: 0.8766
# Epoch 83: val_accuracy did not improve from 0.88363
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3545 - accuracy: 0.8766 - val_loss: 0.3206 - val_accuracy: 0.8833 - lr: 5.0000e-04
# Epoch 84/100
# 2991/2997 [============================>.] - ETA: 0s - loss: 0.3516 - accuracy: 0.8774
# Epoch 84: val_accuracy did not improve from 0.88363
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3519 - accuracy: 0.8773 - val_loss: 0.3182 - val_accuracy: 0.8830 - lr: 5.0000e-04
# Epoch 85/100
# 2971/2997 [============================>.] - ETA: 0s - loss: 0.3508 - accuracy: 0.8773
# Epoch 85: val_accuracy did not improve from 0.88363
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3502 - accuracy: 0.8773 - val_loss: 0.3295 - val_accuracy: 0.8794 - lr: 5.0000e-04
# Epoch 86/100
# 2972/2997 [============================>.] - ETA: 0s - loss: 0.3505 - accuracy: 0.8769
# Epoch 86: val_accuracy did not improve from 0.88363
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3501 - accuracy: 0.8770 - val_loss: 0.3224 - val_accuracy: 0.8830 - lr: 5.0000e-04
# Epoch 87/100
# 2987/2997 [============================>.] - ETA: 0s - loss: 0.3472 - accuracy: 0.8781
# Epoch 87: val_accuracy did not improve from 0.88363
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3473 - accuracy: 0.8780 - val_loss: 0.3254 - val_accuracy: 0.8832 - lr: 5.0000e-04
# Epoch 88/100
# 2994/2997 [============================>.] - ETA: 0s - loss: 0.3482 - accuracy: 0.8779
# Epoch 88: val_accuracy improved from 0.88363 to 0.88410, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3481 - accuracy: 0.8779 - val_loss: 0.3190 - val_accuracy: 0.8841 - lr: 5.0000e-04
# Epoch 89/100
# 2989/2997 [============================>.] - ETA: 0s - loss: 0.3441 - accuracy: 0.8793
# Epoch 89: val_accuracy improved from 0.88410 to 0.88493, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3439 - accuracy: 0.8793 - val_loss: 0.3162 - val_accuracy: 0.8849 - lr: 5.0000e-04
# Epoch 90/100
# 2973/2997 [============================>.] - ETA: 0s - loss: 0.3448 - accuracy: 0.8779
# Epoch 90: val_accuracy did not improve from 0.88493
# 2997/2997 [==============================] - 6s 2ms/step - loss: 0.3448 - accuracy: 0.8780 - val_loss: 0.3211 - val_accuracy: 0.8827 - lr: 5.0000e-04
# Epoch 91/100
# 2979/2997 [============================>.] - ETA: 0s - loss: 0.3445 - accuracy: 0.8779
# Epoch 91: val_accuracy did not improve from 0.88493
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3443 - accuracy: 0.8780 - val_loss: 0.3182 - val_accuracy: 0.8829 - lr: 5.0000e-04
# Epoch 92/100
# 2986/2997 [============================>.] - ETA: 0s - loss: 0.3438 - accuracy: 0.8780
# Epoch 92: val_accuracy did not improve from 0.88493
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3439 - accuracy: 0.8781 - val_loss: 0.3147 - val_accuracy: 0.8843 - lr: 5.0000e-04
# Epoch 93/100
# 2981/2997 [============================>.] - ETA: 0s - loss: 0.3405 - accuracy: 0.8806
# Epoch 93: val_accuracy did not improve from 0.88493
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3406 - accuracy: 0.8805 - val_loss: 0.3227 - val_accuracy: 0.8837 - lr: 5.0000e-04
# Epoch 94/100
# 2967/2997 [============================>.] - ETA: 0s - loss: 0.3396 - accuracy: 0.8801
# Epoch 94: val_accuracy did not improve from 0.88493
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.3397 - accuracy: 0.8800 - val_loss: 0.3194 - val_accuracy: 0.8841 - lr: 5.0000e-04
# Epoch 95/100
# 2989/2997 [============================>.] - ETA: 0s - loss: 0.3390 - accuracy: 0.8797
# Epoch 95: val_accuracy improved from 0.88493 to 0.88664, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 12s 4ms/step - loss: 0.3390 - accuracy: 0.8797 - val_loss: 0.3125 - val_accuracy: 0.8866 - lr: 5.0000e-04
# Epoch 96/100
# 2995/2997 [============================>.] - ETA: 0s - loss: 0.3393 - accuracy: 0.8798
# Epoch 96: val_accuracy did not improve from 0.88664
# 2997/2997 [==============================] - 13s 4ms/step - loss: 0.3392 - accuracy: 0.8798 - val_loss: 0.3162 - val_accuracy: 0.8845 - lr: 5.0000e-04
# Epoch 97/100
# 2995/2997 [============================>.] - ETA: 0s - loss: 0.3383 - accuracy: 0.8810
# Epoch 97: val_accuracy did not improve from 0.88664
# 2997/2997 [==============================] - 13s 4ms/step - loss: 0.3383 - accuracy: 0.8810 - val_loss: 0.3137 - val_accuracy: 0.8840 - lr: 5.0000e-04
# Epoch 98/100
# 2987/2997 [============================>.] - ETA: 0s - loss: 0.3382 - accuracy: 0.8811
# Epoch 98: val_accuracy did not improve from 0.88664
# 2997/2997 [==============================] - 13s 4ms/step - loss: 0.3385 - accuracy: 0.8811 - val_loss: 0.3152 - val_accuracy: 0.8850 - lr: 5.0000e-04
# Epoch 99/100
# 2987/2997 [============================>.] - ETA: 0s - loss: 0.3348 - accuracy: 0.8813
# Epoch 99: val_accuracy did not improve from 0.88664
# 2997/2997 [==============================] - 13s 4ms/step - loss: 0.3348 - accuracy: 0.8813 - val_loss: 0.3141 - val_accuracy: 0.8842 - lr: 5.0000e-04
# Epoch 100/100
# 2988/2997 [============================>.] - ETA: 0s - loss: 0.3343 - accuracy: 0.8811
# Epoch 100: val_accuracy did not improve from 0.88664
# 2997/2997 [==============================] - 13s 4ms/step - loss: 0.3344 - accuracy: 0.8810 - val_loss: 0.3268 - val_accuracy: 0.8808 - lr: 5.0000e-04

# %%
# 학습 결과 시각화
# Train 및 Validation Accuracy 데이터
train_accuracy = history_balance.history['accuracy']
val_accuracy = history_balance.history['val_accuracy']
train_loss = history_balance.history['loss']
val_loss = history_balance.history['val_loss']

# 그래프 생성
plt.figure(figsize=(10, 6))

# Train Accuracy 그래프
plt.plot(range(1, len(train_accuracy) + 1), train_accuracy, label='Train Accuracy')

# Validation Accuracy 그래프
plt.plot(range(1, len(val_accuracy) + 1), val_accuracy, label='Validation Accuracy')

plt.plot(range(1, len(train_accuracy) + 1), train_loss, label='Train Loss')

plt.plot(range(1, len(train_accuracy) + 1), val_loss, label='Validation Loss')
# 그래프 제목 및 축 레이블
plt.title('Model Accuracy with ResNet-34 (Training with bybalanced)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.ylim(0, 1)
plt.yticks(np.arange(0, 1.1, 0.05))

# 범례 추가
plt.legend()

# 그래프 출력
plt.show()

# %%
# Evaluate model
start_time = time.time()  # 추론 시작 시간
predictions = model.predict(test_x_balance)
end_time = time.time()  # 추론 종료 시간
total_inference_time = end_time - start_time
average_inference_time = total_inference_time / len(test_x_balance)

# 테스트 데이터에 대한 예측 결과 처리
predicted_classes = np.argmax(predictions, axis=1)
actual_classes = np.argmax(test_y_balance, axis=1)

# 정확도 계산
correct_predictions = np.sum(predicted_classes == actual_classes)
accuracy = correct_predictions / len(predicted_classes)

# 결과 출력
print(f"Correct Predictions: {correct_predictions}")
print(f"Total Predictions: {len(predicted_classes)}")
print(f"정확도: {accuracy:.4f}")
print(f"훈련시간 : {training_time:.2f} seconds.")
print(f"평균 추론 시간: {average_inference_time:.4f} seconds.") #각 샘플에 대한 추론 시간을 개별적으로 측정함으로써, 추론에 필요한 시간을 더 정확히 파악
# Out:
# Correct Predictions: 16523
# Total Predictions: 18799
# 정확도: 0.8789
# 훈련시간 : 747.62 seconds.
# 평균 추론 시간: 0.0000 seconds.

# %% [markdown]
# -------------------
