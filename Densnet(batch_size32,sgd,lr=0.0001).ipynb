# %% [markdown]
# ### `Basic setting`

# %%
import sys

assert sys.version_info >= (3, 7)

from packaging import version
import sklearn
print("sklearn version: ", sklearn.__version__)
assert version.parse(sklearn.__version__) >= version.parse("1.0.1")

import tensorflow as tf
print("TF version: ", tf.__version__)
assert version.parse(tf.__version__) >= version.parse("2.8.0")

import matplotlib.pyplot as plt

# Is this notebook running on Colab or Kaggle?
IS_COLAB = "google.colab" in sys.modules
IS_KAGGLE = "kaggle_secrets" in sys.modules

if not tf.config.list_physical_devices('GPU'):
    print("No GPU was detected. Neural nets can be very slow without a GPU.")
    if IS_COLAB:
        print("Go to Runtime > Change runtime and select a GPU hardware "
              "accelerator.")
    if IS_KAGGLE:
        print("Go to Settings > Accelerator and select GPU.")


# To prevent "CUDNN_STATUS_ALLOC_FAILED" error with GPUs
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# sklearn version:  1.0.2
# TF version:  2.8.0
# 1 Physical GPUs, 1 Logical GPUs

# %%
import os
import time
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Flatten, Dense, Dropout, BatchNormalization, LeakyReLU, ReLU, ELU
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD
np.random.seed(42)

# %%
# check GPU
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 12518361303898997723
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 2466897916
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 10039676196652059319
#  physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6"
#  xla_global_id: 416903419]

# %% [markdown]
# ### `Load dataset (by_merge)`

# %%
# Hyper parameter setting
BATCH_SIZE = 32
EPOCHS = 100
VALIDATION_SPLIT = 0.15
LEARNING_RATE = 0.0001
PATIENCE = 10
MIN_LEARNING_RATE = 0.0001
DECAY_FACTOR = 0.2
DENSE_LAYER_ACTIVATION = 'elu'
FINAL_LAYER_ACTIVATION = 'softmax'
LOSS_FUNCTION = 'categorical_crossentropy'
METRICS = ['accuracy']
optimizer = SGD(learning_rate=LEARNING_RATE)

CHECK_POINT_BALANCE = 'Best_points_densenet.h'

# %% [markdown]
# ### `Load dataset (by_balanced)`

# %%
# 데이터 불러오기
testing_set_balance = pd.read_csv('emnist-balanced-test.csv')
training_set_balance = pd.read_csv('emnist-balanced-train.csv')


# 훈련 데이터와 레이블 추출
train_y_balance = np.array(training_set_balance.iloc[:, 0].values)
train_x_balance = np.array(training_set_balance.iloc[:, 1:].values)

# 테스트 데이터와 레이블 추출
test_y_balance = np.array(testing_set_balance.iloc[:, 0].values)
test_x_balance = np.array(testing_set_balance.iloc[:, 1:].values)

# 데이터 정규화
train_x_balance = train_x_balance / 255.0
test_x_balance = test_x_balance / 255.0

# 이미지 크기 재조정 (데이터 차원 변경)
images_height = 28
images_width = 28
train_x_balance = train_x_balance.reshape(train_x_balance.shape[0], images_height, images_width, 1)
test_x_balance = test_x_balance.reshape(test_x_balance.shape[0], images_height, images_width, 1)

# 클래스 수 = 47
number_of_classes = 47

# 레이블 원-핫 인코딩
train_y_balance = tf.keras.utils.to_categorical(train_y_balance, number_of_classes)
test_y_balance = tf.keras.utils.to_categorical(test_y_balance, number_of_classes)

#VALIDATION_SPLIT = 0.15
train_x_balance, val_x_balance, train_y_balance, val_y_balance = train_test_split(train_x_balance, train_y_balance, 
                                                                              test_size=VALIDATION_SPLIT, random_state=42)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau,ModelCheckpoint
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Conv2D, Input,MaxPooling2D, Dense, Flatten ,Activation ,  BatchNormalization , Dropout ,AveragePooling2D
from tensorflow.keras.models import Model
from functools import partial

# %% [markdown]
# #### Training PersonalModelwith bybalanced dataset

# %%
# Define Densenet
model = tf.keras.Sequential([
    Conv2D(16, kernel_size=(5, 5), activation=DENSE_LAYER_ACTIVATION, input_shape=(28, 28, 1), padding='same'),
    AveragePooling2D(),
    # Conv2D(16, kernel_size=(3, 3), activation=DENSE_LAYER_ACTIVATION, padding='same'),
    # BatchNormalization(),
    # AveragePooling2D(),
    Conv2D(32, kernel_size=(5, 5), activation=DENSE_LAYER_ACTIVATION, padding='same'),
    BatchNormalization(),
    AveragePooling2D(),
    Conv2D(64, kernel_size=(5, 5), activation=DENSE_LAYER_ACTIVATION, padding='same'),
    BatchNormalization(),
    AveragePooling2D(),
    Conv2D(128, kernel_size=(5, 5), activation=DENSE_LAYER_ACTIVATION, padding='same'),
    BatchNormalization(),
    AveragePooling2D(pool_size=(1, 1)),
    Flatten(),
    Dense(128, activation=DENSE_LAYER_ACTIVATION),
    Dropout(0.5),
    Dense(number_of_classes, activation=FINAL_LAYER_ACTIVATION)
])

#model.summary()

# %%
# 모델 컴파일
#LOSS_FUNCTION = 'categorical_crossentropy'
#LEARNING_RATE = 0.001
#METRICS = ['accuracy']

model.compile(optimizer=optimizer,
            loss=LOSS_FUNCTION,
            metrics=METRICS)

# 콜백 설정
#DECAY_FACTOR = 0.2
#PATIENCE = 3
#MIN_LEARNING_RATE = 0.0001

callbacks_balance = [
    ModelCheckpoint(CHECK_POINT_BALANCE, verbose=1, save_best_only=True, monitor='val_accuracy', mode='max'),
    EarlyStopping(monitor='val_accuracy', restore_best_weights=True, patience=PATIENCE, mode='max'),
    ReduceLROnPlateau(monitor='val_loss', patience=PATIENCE, factor=DECAY_FACTOR, min_lr=MIN_LEARNING_RATE)
]

# %%
start_time = time.time()  # 학습 시작 시간

# 모델 학습
history_balance = model.fit(train_x_balance, train_y_balance, batch_size=BATCH_SIZE, epochs=EPOCHS, 
                                validation_data=(val_x_balance, val_y_balance), callbacks=callbacks_balance)

training_time = time.time() - start_time
# Out:
# Epoch 1/100
# 2997/2997 [==============================] - ETA: 0s - loss: 2.9509 - accuracy: 0.2265
# Epoch 1: val_accuracy improved from -inf to 0.51076, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 10s 3ms/step - loss: 2.9509 - accuracy: 0.2265 - val_loss: 2.0438 - val_accuracy: 0.5108 - lr: 1.0000e-04
# Epoch 2/100
# 2990/2997 [============================>.] - ETA: 0s - loss: 2.2709 - accuracy: 0.3803
# Epoch 2: val_accuracy improved from 0.51076 to 0.57571, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 2.2710 - accuracy: 0.3803 - val_loss: 1.7257 - val_accuracy: 0.5757 - lr: 1.0000e-04
# Epoch 3/100
# 2987/2997 [============================>.] - ETA: 0s - loss: 2.0611 - accuracy: 0.4325
# Epoch 3: val_accuracy improved from 0.57571 to 0.60892, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 2.0607 - accuracy: 0.4327 - val_loss: 1.5611 - val_accuracy: 0.6089 - lr: 1.0000e-04
# Epoch 4/100
# 2988/2997 [============================>.] - ETA: 0s - loss: 1.9233 - accuracy: 0.4698
# Epoch 4: val_accuracy improved from 0.60892 to 0.63109, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 1.9231 - accuracy: 0.4698 - val_loss: 1.4539 - val_accuracy: 0.6311 - lr: 1.0000e-04
# Epoch 5/100
# 2992/2997 [============================>.] - ETA: 0s - loss: 1.8209 - accuracy: 0.4946
# Epoch 5: val_accuracy improved from 0.63109 to 0.64935, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 1.8208 - accuracy: 0.4947 - val_loss: 1.3581 - val_accuracy: 0.6493 - lr: 1.0000e-04
# Epoch 6/100
# 2971/2997 [============================>.] - ETA: 0s - loss: 1.7254 - accuracy: 0.5193
# Epoch 6: val_accuracy improved from 0.64935 to 0.66513, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 1.7254 - accuracy: 0.5194 - val_loss: 1.2866 - val_accuracy: 0.6651 - lr: 1.0000e-04
# Epoch 7/100
# 2988/2997 [============================>.] - ETA: 0s - loss: 1.6409 - accuracy: 0.5424
# Epoch 7: val_accuracy improved from 0.66513 to 0.67819, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 1.6406 - accuracy: 0.5425 - val_loss: 1.2142 - val_accuracy: 0.6782 - lr: 1.0000e-04
# Epoch 8/100
# 2967/2997 [============================>.] - ETA: 0s - loss: 1.5640 - accuracy: 0.5604
# Epoch 8: val_accuracy improved from 0.67819 to 0.69291, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 1.5637 - accuracy: 0.5606 - val_loss: 1.1510 - val_accuracy: 0.6929 - lr: 1.0000e-04
# Epoch 9/100
# 2972/2997 [============================>.] - ETA: 0s - loss: 1.5005 - accuracy: 0.5765
# Epoch 9: val_accuracy improved from 0.69291 to 0.70319, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 1.4995 - accuracy: 0.5767 - val_loss: 1.0956 - val_accuracy: 0.7032 - lr: 1.0000e-04
# Epoch 10/100
# 2985/2997 [============================>.] - ETA: 0s - loss: 1.4361 - accuracy: 0.5916
# Epoch 10: val_accuracy improved from 0.70319 to 0.71584, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 1.4356 - accuracy: 0.5918 - val_loss: 1.0399 - val_accuracy: 0.7158 - lr: 1.0000e-04
# Epoch 11/100
# 2986/2997 [============================>.] - ETA: 0s - loss: 1.3724 - accuracy: 0.6078
# Epoch 11: val_accuracy improved from 0.71584 to 0.72524, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 1.3722 - accuracy: 0.6078 - val_loss: 0.9951 - val_accuracy: 0.7252 - lr: 1.0000e-04
# Epoch 12/100
# 2984/2997 [============================>.] - ETA: 0s - loss: 1.3206 - accuracy: 0.6219
# Epoch 12: val_accuracy improved from 0.72524 to 0.73546, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 1.3206 - accuracy: 0.6218 - val_loss: 0.9597 - val_accuracy: 0.7355 - lr: 1.0000e-04
# Epoch 13/100
# 2991/2997 [============================>.] - ETA: 0s - loss: 1.2681 - accuracy: 0.6360
# Epoch 13: val_accuracy improved from 0.73546 to 0.74208, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 1.2678 - accuracy: 0.6361 - val_loss: 0.9185 - val_accuracy: 0.7421 - lr: 1.0000e-04
# Epoch 14/100
# 2997/2997 [==============================] - ETA: 0s - loss: 1.2226 - accuracy: 0.6484
# Epoch 14: val_accuracy improved from 0.74208 to 0.75609, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 1.2226 - accuracy: 0.6484 - val_loss: 0.8719 - val_accuracy: 0.7561 - lr: 1.0000e-04
# Epoch 15/100
# 2969/2997 [============================>.] - ETA: 0s - loss: 1.1851 - accuracy: 0.6568
# Epoch 15: val_accuracy improved from 0.75609 to 0.76336, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 1.1851 - accuracy: 0.6568 - val_loss: 0.8405 - val_accuracy: 0.7634 - lr: 1.0000e-04
# Epoch 16/100
# 2990/2997 [============================>.] - ETA: 0s - loss: 1.1402 - accuracy: 0.6680
# Epoch 16: val_accuracy improved from 0.76336 to 0.76779, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 1.1405 - accuracy: 0.6679 - val_loss: 0.8141 - val_accuracy: 0.7678 - lr: 1.0000e-04
# Epoch 17/100
# 2973/2997 [============================>.] - ETA: 0s - loss: 1.1138 - accuracy: 0.6740
# Epoch 17: val_accuracy improved from 0.76779 to 0.77299, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 1.1135 - accuracy: 0.6741 - val_loss: 0.7891 - val_accuracy: 0.7730 - lr: 1.0000e-04
# Epoch 18/100
# 2971/2997 [============================>.] - ETA: 0s - loss: 1.0824 - accuracy: 0.6820
# Epoch 18: val_accuracy improved from 0.77299 to 0.77671, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 1.0823 - accuracy: 0.6821 - val_loss: 0.7726 - val_accuracy: 0.7767 - lr: 1.0000e-04
# Epoch 19/100
# 2968/2997 [============================>.] - ETA: 0s - loss: 1.0564 - accuracy: 0.6903
# Epoch 19: val_accuracy improved from 0.77671 to 0.78339, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 1.0562 - accuracy: 0.6902 - val_loss: 0.7461 - val_accuracy: 0.7834 - lr: 1.0000e-04
# Epoch 20/100
# 2982/2997 [============================>.] - ETA: 0s - loss: 1.0321 - accuracy: 0.6965
# Epoch 20: val_accuracy improved from 0.78339 to 0.78452, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 1.0321 - accuracy: 0.6965 - val_loss: 0.7371 - val_accuracy: 0.7845 - lr: 1.0000e-04
# Epoch 21/100
# 2970/2997 [============================>.] - ETA: 0s - loss: 1.0094 - accuracy: 0.6995
# Epoch 21: val_accuracy improved from 0.78452 to 0.78457, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 1.0092 - accuracy: 0.6996 - val_loss: 0.7201 - val_accuracy: 0.7846 - lr: 1.0000e-04
# Epoch 22/100
# 2968/2997 [============================>.] - ETA: 0s - loss: 0.9879 - accuracy: 0.7070
# Epoch 22: val_accuracy improved from 0.78457 to 0.79054, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.9878 - accuracy: 0.7070 - val_loss: 0.7045 - val_accuracy: 0.7905 - lr: 1.0000e-04
# Epoch 23/100
# 2983/2997 [============================>.] - ETA: 0s - loss: 0.9731 - accuracy: 0.7104
# Epoch 23: val_accuracy improved from 0.79054 to 0.79533, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.9725 - accuracy: 0.7106 - val_loss: 0.6842 - val_accuracy: 0.7953 - lr: 1.0000e-04
# Epoch 24/100
# 2981/2997 [============================>.] - ETA: 0s - loss: 0.9497 - accuracy: 0.7168
# Epoch 24: val_accuracy improved from 0.79533 to 0.79770, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.9497 - accuracy: 0.7166 - val_loss: 0.6751 - val_accuracy: 0.7977 - lr: 1.0000e-04
# Epoch 25/100
# 2995/2997 [============================>.] - ETA: 0s - loss: 0.9361 - accuracy: 0.7216
# Epoch 25: val_accuracy improved from 0.79770 to 0.79970, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.9362 - accuracy: 0.7216 - val_loss: 0.6611 - val_accuracy: 0.7997 - lr: 1.0000e-04
# Epoch 26/100
# 2995/2997 [============================>.] - ETA: 0s - loss: 0.9195 - accuracy: 0.7242
# Epoch 26: val_accuracy improved from 0.79970 to 0.80491, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.9194 - accuracy: 0.7242 - val_loss: 0.6528 - val_accuracy: 0.8049 - lr: 1.0000e-04
# Epoch 27/100
# 2967/2997 [============================>.] - ETA: 0s - loss: 0.9018 - accuracy: 0.7305
# Epoch 27: val_accuracy did not improve from 0.80491
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.9018 - accuracy: 0.7305 - val_loss: 0.6455 - val_accuracy: 0.8028 - lr: 1.0000e-04
# Epoch 28/100
# 2966/2997 [============================>.] - ETA: 0s - loss: 0.8909 - accuracy: 0.7336
# Epoch 28: val_accuracy improved from 0.80491 to 0.80934, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.8906 - accuracy: 0.7337 - val_loss: 0.6289 - val_accuracy: 0.8093 - lr: 1.0000e-04
# Epoch 29/100
# 2976/2997 [============================>.] - ETA: 0s - loss: 0.8760 - accuracy: 0.7362
# Epoch 29: val_accuracy did not improve from 0.80934
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.8759 - accuracy: 0.7362 - val_loss: 0.6302 - val_accuracy: 0.8057 - lr: 1.0000e-04
# Epoch 30/100
# 2991/2997 [============================>.] - ETA: 0s - loss: 0.8626 - accuracy: 0.7395
# Epoch 30: val_accuracy improved from 0.80934 to 0.81241, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.8626 - accuracy: 0.7395 - val_loss: 0.6124 - val_accuracy: 0.8124 - lr: 1.0000e-04
# Epoch 31/100
# 2971/2997 [============================>.] - ETA: 0s - loss: 0.8467 - accuracy: 0.7437
# Epoch 31: val_accuracy improved from 0.81241 to 0.81531, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 8s 3ms/step - loss: 0.8471 - accuracy: 0.7435 - val_loss: 0.6018 - val_accuracy: 0.8153 - lr: 1.0000e-04
# Epoch 32/100
# 2975/2997 [============================>.] - ETA: 0s - loss: 0.8383 - accuracy: 0.7469
# Epoch 32: val_accuracy did not improve from 0.81531
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.8381 - accuracy: 0.7468 - val_loss: 0.6008 - val_accuracy: 0.8145 - lr: 1.0000e-04
# Epoch 33/100
# 2979/2997 [============================>.] - ETA: 0s - loss: 0.8261 - accuracy: 0.7493
# Epoch 33: val_accuracy improved from 0.81531 to 0.81696, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 8s 3ms/step - loss: 0.8255 - accuracy: 0.7495 - val_loss: 0.5876 - val_accuracy: 0.8170 - lr: 1.0000e-04
# Epoch 34/100
# 2987/2997 [============================>.] - ETA: 0s - loss: 0.8169 - accuracy: 0.7518
# Epoch 34: val_accuracy improved from 0.81696 to 0.81773, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.8171 - accuracy: 0.7517 - val_loss: 0.5842 - val_accuracy: 0.8177 - lr: 1.0000e-04
# Epoch 35/100
# 2980/2997 [============================>.] - ETA: 0s - loss: 0.8071 - accuracy: 0.7553
# Epoch 35: val_accuracy improved from 0.81773 to 0.82169, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.8070 - accuracy: 0.7554 - val_loss: 0.5730 - val_accuracy: 0.8217 - lr: 1.0000e-04
# Epoch 36/100
# 2993/2997 [============================>.] - ETA: 0s - loss: 0.7971 - accuracy: 0.7582
# Epoch 36: val_accuracy improved from 0.82169 to 0.82323, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.7970 - accuracy: 0.7583 - val_loss: 0.5667 - val_accuracy: 0.8232 - lr: 1.0000e-04
# Epoch 37/100
# 2977/2997 [============================>.] - ETA: 0s - loss: 0.7881 - accuracy: 0.7601
# Epoch 37: val_accuracy improved from 0.82323 to 0.82559, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.7881 - accuracy: 0.7601 - val_loss: 0.5575 - val_accuracy: 0.8256 - lr: 1.0000e-04
# Epoch 38/100
# 2977/2997 [============================>.] - ETA: 0s - loss: 0.7762 - accuracy: 0.7616
# Epoch 38: val_accuracy did not improve from 0.82559
# 2997/2997 [==============================] - 6s 2ms/step - loss: 0.7761 - accuracy: 0.7617 - val_loss: 0.5605 - val_accuracy: 0.8247 - lr: 1.0000e-04
# Epoch 39/100
# 2997/2997 [==============================] - ETA: 0s - loss: 0.7673 - accuracy: 0.7655
# Epoch 39: val_accuracy did not improve from 0.82559
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.7673 - accuracy: 0.7655 - val_loss: 0.5551 - val_accuracy: 0.8245 - lr: 1.0000e-04
# Epoch 40/100
# 2992/2997 [============================>.] - ETA: 0s - loss: 0.7600 - accuracy: 0.7675
# Epoch 40: val_accuracy did not improve from 0.82559
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.7599 - accuracy: 0.7675 - val_loss: 0.5500 - val_accuracy: 0.8240 - lr: 1.0000e-04
# Epoch 41/100
# 2969/2997 [============================>.] - ETA: 0s - loss: 0.7520 - accuracy: 0.7693
# Epoch 41: val_accuracy improved from 0.82559 to 0.82648, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.7515 - accuracy: 0.7695 - val_loss: 0.5464 - val_accuracy: 0.8265 - lr: 1.0000e-04
# Epoch 42/100
# 2985/2997 [============================>.] - ETA: 0s - loss: 0.7419 - accuracy: 0.7728
# Epoch 42: val_accuracy improved from 0.82648 to 0.83002, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.7420 - accuracy: 0.7729 - val_loss: 0.5333 - val_accuracy: 0.8300 - lr: 1.0000e-04
# Epoch 43/100
# 2986/2997 [============================>.] - ETA: 0s - loss: 0.7396 - accuracy: 0.7728
# Epoch 43: val_accuracy improved from 0.83002 to 0.83215, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.7396 - accuracy: 0.7729 - val_loss: 0.5320 - val_accuracy: 0.8322 - lr: 1.0000e-04
# Epoch 44/100
# 2984/2997 [============================>.] - ETA: 0s - loss: 0.7276 - accuracy: 0.7765
# Epoch 44: val_accuracy improved from 0.83215 to 0.83257, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.7277 - accuracy: 0.7764 - val_loss: 0.5248 - val_accuracy: 0.8326 - lr: 1.0000e-04
# Epoch 45/100
# 2986/2997 [============================>.] - ETA: 0s - loss: 0.7230 - accuracy: 0.7775
# Epoch 45: val_accuracy improved from 0.83257 to 0.83440, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.7229 - accuracy: 0.7774 - val_loss: 0.5210 - val_accuracy: 0.8344 - lr: 1.0000e-04
# Epoch 46/100
# 2980/2997 [============================>.] - ETA: 0s - loss: 0.7162 - accuracy: 0.7779
# Epoch 46: val_accuracy did not improve from 0.83440
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.7159 - accuracy: 0.7780 - val_loss: 0.5233 - val_accuracy: 0.8326 - lr: 1.0000e-04
# Epoch 47/100
# 2977/2997 [============================>.] - ETA: 0s - loss: 0.7113 - accuracy: 0.7794
# Epoch 47: val_accuracy did not improve from 0.83440
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.7109 - accuracy: 0.7796 - val_loss: 0.5188 - val_accuracy: 0.8337 - lr: 1.0000e-04
# Epoch 48/100
# 2996/2997 [============================>.] - ETA: 0s - loss: 0.7045 - accuracy: 0.7815
# Epoch 48: val_accuracy did not improve from 0.83440
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.7045 - accuracy: 0.7814 - val_loss: 0.5125 - val_accuracy: 0.8335 - lr: 1.0000e-04
# Epoch 49/100
# 2992/2997 [============================>.] - ETA: 0s - loss: 0.6994 - accuracy: 0.7829
# Epoch 49: val_accuracy improved from 0.83440 to 0.83842, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.6994 - accuracy: 0.7829 - val_loss: 0.5078 - val_accuracy: 0.8384 - lr: 1.0000e-04
# Epoch 50/100
# 2985/2997 [============================>.] - ETA: 0s - loss: 0.6914 - accuracy: 0.7848
# Epoch 50: val_accuracy did not improve from 0.83842
# 2997/2997 [==============================] - 6s 2ms/step - loss: 0.6917 - accuracy: 0.7847 - val_loss: 0.5224 - val_accuracy: 0.8307 - lr: 1.0000e-04
# Epoch 51/100
# 2982/2997 [============================>.] - ETA: 0s - loss: 0.6884 - accuracy: 0.7863
# Epoch 51: val_accuracy did not improve from 0.83842
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.6878 - accuracy: 0.7864 - val_loss: 0.4990 - val_accuracy: 0.8374 - lr: 1.0000e-04
# Epoch 52/100
# 2968/2997 [============================>.] - ETA: 0s - loss: 0.6794 - accuracy: 0.7894
# Epoch 52: val_accuracy improved from 0.83842 to 0.84048, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.6794 - accuracy: 0.7895 - val_loss: 0.4961 - val_accuracy: 0.8405 - lr: 1.0000e-04
# Epoch 53/100
# 2997/2997 [==============================] - ETA: 0s - loss: 0.6772 - accuracy: 0.7888
# Epoch 53: val_accuracy did not improve from 0.84048
# 2997/2997 [==============================] - 6s 2ms/step - loss: 0.6772 - accuracy: 0.7888 - val_loss: 0.4917 - val_accuracy: 0.8405 - lr: 1.0000e-04
# Epoch 54/100
# 2995/2997 [============================>.] - ETA: 0s - loss: 0.6705 - accuracy: 0.7910
# Epoch 54: val_accuracy did not improve from 0.84048
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.6705 - accuracy: 0.7910 - val_loss: 0.4904 - val_accuracy: 0.8403 - lr: 1.0000e-04
# Epoch 55/100
# 2978/2997 [============================>.] - ETA: 0s - loss: 0.6660 - accuracy: 0.7927
# Epoch 55: val_accuracy improved from 0.84048 to 0.84232, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.6662 - accuracy: 0.7926 - val_loss: 0.4905 - val_accuracy: 0.8423 - lr: 1.0000e-04
# Epoch 56/100
# 2995/2997 [============================>.] - ETA: 0s - loss: 0.6609 - accuracy: 0.7918
# Epoch 56: val_accuracy did not improve from 0.84232
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.6608 - accuracy: 0.7918 - val_loss: 0.4846 - val_accuracy: 0.8419 - lr: 1.0000e-04
# Epoch 57/100
# 2985/2997 [============================>.] - ETA: 0s - loss: 0.6550 - accuracy: 0.7948
# Epoch 57: val_accuracy improved from 0.84232 to 0.84427, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.6554 - accuracy: 0.7948 - val_loss: 0.4834 - val_accuracy: 0.8443 - lr: 1.0000e-04
# Epoch 58/100
# 2978/2997 [============================>.] - ETA: 0s - loss: 0.6503 - accuracy: 0.7966
# Epoch 58: val_accuracy did not improve from 0.84427
# 2997/2997 [==============================] - 6s 2ms/step - loss: 0.6505 - accuracy: 0.7964 - val_loss: 0.4791 - val_accuracy: 0.8429 - lr: 1.0000e-04
# Epoch 59/100
# 2975/2997 [============================>.] - ETA: 0s - loss: 0.6494 - accuracy: 0.7964
# Epoch 59: val_accuracy did not improve from 0.84427
# 2997/2997 [==============================] - 6s 2ms/step - loss: 0.6493 - accuracy: 0.7964 - val_loss: 0.4785 - val_accuracy: 0.8440 - lr: 1.0000e-04
# Epoch 60/100
# 2989/2997 [============================>.] - ETA: 0s - loss: 0.6431 - accuracy: 0.7981
# Epoch 60: val_accuracy improved from 0.84427 to 0.84486, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.6432 - accuracy: 0.7981 - val_loss: 0.4770 - val_accuracy: 0.8449 - lr: 1.0000e-04
# Epoch 61/100
# 2993/2997 [============================>.] - ETA: 0s - loss: 0.6414 - accuracy: 0.7972
# Epoch 61: val_accuracy improved from 0.84486 to 0.84675, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 8s 3ms/step - loss: 0.6412 - accuracy: 0.7973 - val_loss: 0.4729 - val_accuracy: 0.8467 - lr: 1.0000e-04
# Epoch 62/100
# 2986/2997 [============================>.] - ETA: 0s - loss: 0.6341 - accuracy: 0.8015
# Epoch 62: val_accuracy did not improve from 0.84675
# 2997/2997 [==============================] - 6s 2ms/step - loss: 0.6339 - accuracy: 0.8015 - val_loss: 0.4696 - val_accuracy: 0.8449 - lr: 1.0000e-04
# Epoch 63/100
# 2968/2997 [============================>.] - ETA: 0s - loss: 0.6324 - accuracy: 0.8008
# Epoch 63: val_accuracy did not improve from 0.84675
# 2997/2997 [==============================] - 6s 2ms/step - loss: 0.6320 - accuracy: 0.8009 - val_loss: 0.4691 - val_accuracy: 0.8467 - lr: 1.0000e-04
# Epoch 64/100
# 2978/2997 [============================>.] - ETA: 0s - loss: 0.6242 - accuracy: 0.8030
# Epoch 64: val_accuracy did not improve from 0.84675
# 2997/2997 [==============================] - 6s 2ms/step - loss: 0.6244 - accuracy: 0.8030 - val_loss: 0.4737 - val_accuracy: 0.8439 - lr: 1.0000e-04
# Epoch 65/100
# 2993/2997 [============================>.] - ETA: 0s - loss: 0.6228 - accuracy: 0.8032
# Epoch 65: val_accuracy did not improve from 0.84675
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.6226 - accuracy: 0.8033 - val_loss: 0.4637 - val_accuracy: 0.8456 - lr: 1.0000e-04
# Epoch 66/100
# 2990/2997 [============================>.] - ETA: 0s - loss: 0.6195 - accuracy: 0.8038
# Epoch 66: val_accuracy did not improve from 0.84675
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.6194 - accuracy: 0.8038 - val_loss: 0.4619 - val_accuracy: 0.8465 - lr: 1.0000e-04
# Epoch 67/100
# 2987/2997 [============================>.] - ETA: 0s - loss: 0.6137 - accuracy: 0.8064
# Epoch 67: val_accuracy improved from 0.84675 to 0.84994, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.6138 - accuracy: 0.8063 - val_loss: 0.4589 - val_accuracy: 0.8499 - lr: 1.0000e-04
# Epoch 68/100
# 2971/2997 [============================>.] - ETA: 0s - loss: 0.6101 - accuracy: 0.8059
# Epoch 68: val_accuracy did not improve from 0.84994
# 2997/2997 [==============================] - 6s 2ms/step - loss: 0.6105 - accuracy: 0.8057 - val_loss: 0.4531 - val_accuracy: 0.8488 - lr: 1.0000e-04
# Epoch 69/100
# 2974/2997 [============================>.] - ETA: 0s - loss: 0.6092 - accuracy: 0.8066
# Epoch 69: val_accuracy did not improve from 0.84994
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.6094 - accuracy: 0.8066 - val_loss: 0.4546 - val_accuracy: 0.8498 - lr: 1.0000e-04
# Epoch 70/100
# 2975/2997 [============================>.] - ETA: 0s - loss: 0.6062 - accuracy: 0.8064
# Epoch 70: val_accuracy improved from 0.84994 to 0.85030, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.6061 - accuracy: 0.8065 - val_loss: 0.4509 - val_accuracy: 0.8503 - lr: 1.0000e-04
# Epoch 71/100
# 2972/2997 [============================>.] - ETA: 0s - loss: 0.6007 - accuracy: 0.8106
# Epoch 71: val_accuracy did not improve from 0.85030
# 2997/2997 [==============================] - 6s 2ms/step - loss: 0.6009 - accuracy: 0.8106 - val_loss: 0.4588 - val_accuracy: 0.8462 - lr: 1.0000e-04
# Epoch 72/100
# 2978/2997 [============================>.] - ETA: 0s - loss: 0.5984 - accuracy: 0.8094
# Epoch 72: val_accuracy improved from 0.85030 to 0.85118, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5987 - accuracy: 0.8094 - val_loss: 0.4491 - val_accuracy: 0.8512 - lr: 1.0000e-04
# Epoch 73/100
# 2986/2997 [============================>.] - ETA: 0s - loss: 0.5982 - accuracy: 0.8110
# Epoch 73: val_accuracy improved from 0.85118 to 0.85177, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5981 - accuracy: 0.8109 - val_loss: 0.4468 - val_accuracy: 0.8518 - lr: 1.0000e-04
# Epoch 74/100
# 2988/2997 [============================>.] - ETA: 0s - loss: 0.5938 - accuracy: 0.8111
# Epoch 74: val_accuracy did not improve from 0.85177
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5937 - accuracy: 0.8112 - val_loss: 0.4456 - val_accuracy: 0.8509 - lr: 1.0000e-04
# Epoch 75/100
# 2981/2997 [============================>.] - ETA: 0s - loss: 0.5895 - accuracy: 0.8121
# Epoch 75: val_accuracy did not improve from 0.85177
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5894 - accuracy: 0.8122 - val_loss: 0.4431 - val_accuracy: 0.8499 - lr: 1.0000e-04
# Epoch 76/100
# 2971/2997 [============================>.] - ETA: 0s - loss: 0.5898 - accuracy: 0.8123
# Epoch 76: val_accuracy improved from 0.85177 to 0.85402, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5896 - accuracy: 0.8122 - val_loss: 0.4406 - val_accuracy: 0.8540 - lr: 1.0000e-04
# Epoch 77/100
# 2967/2997 [============================>.] - ETA: 0s - loss: 0.5835 - accuracy: 0.8142
# Epoch 77: val_accuracy did not improve from 0.85402
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5833 - accuracy: 0.8142 - val_loss: 0.4447 - val_accuracy: 0.8509 - lr: 1.0000e-04
# Epoch 78/100
# 2989/2997 [============================>.] - ETA: 0s - loss: 0.5810 - accuracy: 0.8134
# Epoch 78: val_accuracy did not improve from 0.85402
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5810 - accuracy: 0.8134 - val_loss: 0.4404 - val_accuracy: 0.8524 - lr: 1.0000e-04
# Epoch 79/100
# 2994/2997 [============================>.] - ETA: 0s - loss: 0.5790 - accuracy: 0.8160
# Epoch 79: val_accuracy did not improve from 0.85402
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5789 - accuracy: 0.8161 - val_loss: 0.4393 - val_accuracy: 0.8529 - lr: 1.0000e-04
# Epoch 80/100
# 2984/2997 [============================>.] - ETA: 0s - loss: 0.5763 - accuracy: 0.8173
# Epoch 80: val_accuracy did not improve from 0.85402
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5765 - accuracy: 0.8174 - val_loss: 0.4350 - val_accuracy: 0.8529 - lr: 1.0000e-04
# Epoch 81/100
# 2970/2997 [============================>.] - ETA: 0s - loss: 0.5746 - accuracy: 0.8157
# Epoch 81: val_accuracy improved from 0.85402 to 0.85473, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5752 - accuracy: 0.8156 - val_loss: 0.4329 - val_accuracy: 0.8547 - lr: 1.0000e-04
# Epoch 82/100
# 2986/2997 [============================>.] - ETA: 0s - loss: 0.5662 - accuracy: 0.8174
# Epoch 82: val_accuracy did not improve from 0.85473
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5668 - accuracy: 0.8172 - val_loss: 0.4359 - val_accuracy: 0.8512 - lr: 1.0000e-04
# Epoch 83/100
# 2975/2997 [============================>.] - ETA: 0s - loss: 0.5697 - accuracy: 0.8172
# Epoch 83: val_accuracy did not improve from 0.85473
# 2997/2997 [==============================] - 6s 2ms/step - loss: 0.5700 - accuracy: 0.8170 - val_loss: 0.4330 - val_accuracy: 0.8528 - lr: 1.0000e-04
# Epoch 84/100
# 2969/2997 [============================>.] - ETA: 0s - loss: 0.5661 - accuracy: 0.8178
# Epoch 84: val_accuracy did not improve from 0.85473
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5662 - accuracy: 0.8179 - val_loss: 0.4294 - val_accuracy: 0.8530 - lr: 1.0000e-04
# Epoch 85/100
# 2987/2997 [============================>.] - ETA: 0s - loss: 0.5645 - accuracy: 0.8186
# Epoch 85: val_accuracy did not improve from 0.85473
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5647 - accuracy: 0.8185 - val_loss: 0.4324 - val_accuracy: 0.8528 - lr: 1.0000e-04
# Epoch 86/100
# 2997/2997 [==============================] - ETA: 0s - loss: 0.5605 - accuracy: 0.8196
# Epoch 86: val_accuracy did not improve from 0.85473
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5605 - accuracy: 0.8196 - val_loss: 0.4310 - val_accuracy: 0.8540 - lr: 1.0000e-04
# Epoch 87/100
# 2983/2997 [============================>.] - ETA: 0s - loss: 0.5574 - accuracy: 0.8216
# Epoch 87: val_accuracy improved from 0.85473 to 0.85532, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5575 - accuracy: 0.8216 - val_loss: 0.4272 - val_accuracy: 0.8553 - lr: 1.0000e-04
# Epoch 88/100
# 2986/2997 [============================>.] - ETA: 0s - loss: 0.5549 - accuracy: 0.8213
# Epoch 88: val_accuracy did not improve from 0.85532
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5551 - accuracy: 0.8213 - val_loss: 0.4242 - val_accuracy: 0.8550 - lr: 1.0000e-04
# Epoch 89/100
# 2981/2997 [============================>.] - ETA: 0s - loss: 0.5543 - accuracy: 0.8210
# Epoch 89: val_accuracy improved from 0.85532 to 0.85709, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5543 - accuracy: 0.8210 - val_loss: 0.4229 - val_accuracy: 0.8571 - lr: 1.0000e-04
# Epoch 90/100
# 2966/2997 [============================>.] - ETA: 0s - loss: 0.5514 - accuracy: 0.8235
# Epoch 90: val_accuracy did not improve from 0.85709
# 2997/2997 [==============================] - 6s 2ms/step - loss: 0.5514 - accuracy: 0.8235 - val_loss: 0.4213 - val_accuracy: 0.8547 - lr: 1.0000e-04
# Epoch 91/100
# 2981/2997 [============================>.] - ETA: 0s - loss: 0.5489 - accuracy: 0.8228
# Epoch 91: val_accuracy improved from 0.85709 to 0.85745, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5490 - accuracy: 0.8226 - val_loss: 0.4212 - val_accuracy: 0.8574 - lr: 1.0000e-04
# Epoch 92/100
# 2974/2997 [============================>.] - ETA: 0s - loss: 0.5476 - accuracy: 0.8227
# Epoch 92: val_accuracy did not improve from 0.85745
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5479 - accuracy: 0.8226 - val_loss: 0.4231 - val_accuracy: 0.8564 - lr: 1.0000e-04
# Epoch 93/100
# 2991/2997 [============================>.] - ETA: 0s - loss: 0.5449 - accuracy: 0.8232
# Epoch 93: val_accuracy did not improve from 0.85745
# 2997/2997 [==============================] - 6s 2ms/step - loss: 0.5447 - accuracy: 0.8233 - val_loss: 0.4213 - val_accuracy: 0.8562 - lr: 1.0000e-04
# Epoch 94/100
# 2971/2997 [============================>.] - ETA: 0s - loss: 0.5436 - accuracy: 0.8259
# Epoch 94: val_accuracy improved from 0.85745 to 0.85768, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5435 - accuracy: 0.8259 - val_loss: 0.4149 - val_accuracy: 0.8577 - lr: 1.0000e-04
# Epoch 95/100
# 2972/2997 [============================>.] - ETA: 0s - loss: 0.5385 - accuracy: 0.8254
# Epoch 95: val_accuracy did not improve from 0.85768
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5391 - accuracy: 0.8251 - val_loss: 0.4204 - val_accuracy: 0.8571 - lr: 1.0000e-04
# Epoch 96/100
# 2971/2997 [============================>.] - ETA: 0s - loss: 0.5387 - accuracy: 0.8255
# Epoch 96: val_accuracy improved from 0.85768 to 0.85816, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 8s 3ms/step - loss: 0.5386 - accuracy: 0.8255 - val_loss: 0.4123 - val_accuracy: 0.8582 - lr: 1.0000e-04
# Epoch 97/100
# 2973/2997 [============================>.] - ETA: 0s - loss: 0.5358 - accuracy: 0.8270
# Epoch 97: val_accuracy improved from 0.85816 to 0.85946, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5356 - accuracy: 0.8269 - val_loss: 0.4129 - val_accuracy: 0.8595 - lr: 1.0000e-04
# Epoch 98/100
# 2984/2997 [============================>.] - ETA: 0s - loss: 0.5322 - accuracy: 0.8273
# Epoch 98: val_accuracy did not improve from 0.85946
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5320 - accuracy: 0.8274 - val_loss: 0.4151 - val_accuracy: 0.8584 - lr: 1.0000e-04
# Epoch 99/100
# 2991/2997 [============================>.] - ETA: 0s - loss: 0.5311 - accuracy: 0.8283
# Epoch 99: val_accuracy did not improve from 0.85946
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5312 - accuracy: 0.8283 - val_loss: 0.4138 - val_accuracy: 0.8585 - lr: 1.0000e-04
# Epoch 100/100
# 2974/2997 [============================>.] - ETA: 0s - loss: 0.5314 - accuracy: 0.8282
# Epoch 100: val_accuracy improved from 0.85946 to 0.85999, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 2997/2997 [==============================] - 7s 2ms/step - loss: 0.5314 - accuracy: 0.8282 - val_loss: 0.4100 - val_accuracy: 0.8600 - lr: 1.0000e-04

# %%
# 학습 결과 시각화
# Train 및 Validation Accuracy 데이터
train_accuracy = history_balance.history['accuracy']
val_accuracy = history_balance.history['val_accuracy']
train_loss = history_balance.history['loss']
val_loss = history_balance.history['val_loss']

# 그래프 생성
plt.figure(figsize=(10, 6))

# Train Accuracy 그래프
plt.plot(range(1, len(train_accuracy) + 1), train_accuracy, label='Train Accuracy')

# Validation Accuracy 그래프
plt.plot(range(1, len(val_accuracy) + 1), val_accuracy, label='Validation Accuracy')

plt.plot(range(1, len(train_accuracy) + 1), train_loss, label='Train Loss')

plt.plot(range(1, len(train_accuracy) + 1), val_loss, label='Validation Loss')
# 그래프 제목 및 축 레이블
plt.title('Model Accuracy with ResNet-34 (Training with bybalanced)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.ylim(0, 1)
plt.yticks(np.arange(0, 1.1, 0.05))

# 범례 추가
plt.legend()

# 그래프 출력
plt.show()

# %%
# Evaluate model
start_time = time.time()  # 추론 시작 시간
predictions = model.predict(test_x_balance)
end_time = time.time()  # 추론 종료 시간
total_inference_time = end_time - start_time
average_inference_time = total_inference_time / len(test_x_balance)

# 테스트 데이터에 대한 예측 결과 처리
predicted_classes = np.argmax(predictions, axis=1)
actual_classes = np.argmax(test_y_balance, axis=1)

# 정확도 계산
correct_predictions = np.sum(predicted_classes == actual_classes)
accuracy = correct_predictions / len(predicted_classes)

# 결과 출력
print(f"Correct Predictions: {correct_predictions}")
print(f"Total Predictions: {len(predicted_classes)}")
print(f"정확도: {accuracy:.4f}")
print(f"훈련시간 : {training_time:.2f} seconds.")
print(f"평균 추론 시간: {average_inference_time:.4f} seconds.") #각 샘플에 대한 추론 시간을 개별적으로 측정함으로써, 추론에 필요한 시간을 더 정확히 파악
# Out:
# Correct Predictions: 16048
# Total Predictions: 18799
# 정확도: 0.8537
# 훈련시간 : 693.31 seconds.
# 평균 추론 시간: 0.0000 seconds.

# %% [markdown]
# -------------------
