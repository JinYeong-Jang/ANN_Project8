# %% [markdown]
# ### `Basic setting`

# %%
import sys

assert sys.version_info >= (3, 7)

from packaging import version
import sklearn
print("sklearn version: ", sklearn.__version__)
assert version.parse(sklearn.__version__) >= version.parse("1.0.1")

import tensorflow as tf
print("TF version: ", tf.__version__)
assert version.parse(tf.__version__) >= version.parse("2.8.0")

import matplotlib.pyplot as plt

# Is this notebook running on Colab or Kaggle?
IS_COLAB = "google.colab" in sys.modules
IS_KAGGLE = "kaggle_secrets" in sys.modules

if not tf.config.list_physical_devices('GPU'):
    print("No GPU was detected. Neural nets can be very slow without a GPU.")
    if IS_COLAB:
        print("Go to Runtime > Change runtime and select a GPU hardware "
              "accelerator.")
    if IS_KAGGLE:
        print("Go to Settings > Accelerator and select GPU.")


# To prevent "CUDNN_STATUS_ALLOC_FAILED" error with GPUs
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# sklearn version:  1.0.2
# TF version:  2.8.0
# 1 Physical GPUs, 1 Logical GPUs

# %%
import os
import time
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Flatten, Dense, Dropout, BatchNormalization, LeakyReLU, ReLU, ELU
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD
np.random.seed(42)

# %%
# check GPU
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 11429018357690081482
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 9879683072
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 10325557272752420430
#  physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6"
#  xla_global_id: 416903419]

# %% [markdown]
# ### `Load dataset (by_merge)`

# %%
# Hyper parameter setting
BATCH_SIZE = 64
EPOCHS = 100
VALIDATION_SPLIT = 0.15
LEARNING_RATE = 0.0005
PATIENCE = 10
MIN_LEARNING_RATE = 0.0001
DECAY_FACTOR = 0.2
DENSE_LAYER_ACTIVATION = 'elu'
FINAL_LAYER_ACTIVATION = 'softmax'
LOSS_FUNCTION = 'categorical_crossentropy'
METRICS = ['accuracy']
optimizer = SGD(learning_rate=LEARNING_RATE)

CHECK_POINT_BALANCE = 'Best_points_densenet.h'

# %% [markdown]
# ### `Load dataset (by_balanced)`

# %%
# 데이터 불러오기
testing_set_balance = pd.read_csv('emnist-balanced-test.csv')
training_set_balance = pd.read_csv('emnist-balanced-train.csv')


# 훈련 데이터와 레이블 추출
train_y_balance = np.array(training_set_balance.iloc[:, 0].values)
train_x_balance = np.array(training_set_balance.iloc[:, 1:].values)

# 테스트 데이터와 레이블 추출
test_y_balance = np.array(testing_set_balance.iloc[:, 0].values)
test_x_balance = np.array(testing_set_balance.iloc[:, 1:].values)

# 데이터 정규화
train_x_balance = train_x_balance / 255.0
test_x_balance = test_x_balance / 255.0

# 이미지 크기 재조정 (데이터 차원 변경)
images_height = 28
images_width = 28
train_x_balance = train_x_balance.reshape(train_x_balance.shape[0], images_height, images_width, 1)
test_x_balance = test_x_balance.reshape(test_x_balance.shape[0], images_height, images_width, 1)

# 클래스 수 = 47
number_of_classes = 47

# 레이블 원-핫 인코딩
train_y_balance = tf.keras.utils.to_categorical(train_y_balance, number_of_classes)
test_y_balance = tf.keras.utils.to_categorical(test_y_balance, number_of_classes)

#VALIDATION_SPLIT = 0.15
train_x_balance, val_x_balance, train_y_balance, val_y_balance = train_test_split(train_x_balance, train_y_balance, 
                                                                              test_size=VALIDATION_SPLIT, random_state=42)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau,ModelCheckpoint
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Conv2D, Input,MaxPooling2D, Dense, Flatten ,Activation ,  BatchNormalization , Dropout ,AveragePooling2D
from tensorflow.keras.models import Model
from functools import partial

# %% [markdown]
# #### Training PersonalModelwith bybalanced dataset

# %%
# Define Densenet
model = tf.keras.Sequential([
    Conv2D(16, kernel_size=(5, 5), activation=DENSE_LAYER_ACTIVATION, input_shape=(28, 28, 1), padding='same'),
    AveragePooling2D(),
    # Conv2D(16, kernel_size=(3, 3), activation=DENSE_LAYER_ACTIVATION, padding='same'),
    # BatchNormalization(),
    # AveragePooling2D(),
    Conv2D(32, kernel_size=(5, 5), activation=DENSE_LAYER_ACTIVATION, padding='same'),
    BatchNormalization(),
    AveragePooling2D(),
    Conv2D(64, kernel_size=(5, 5), activation=DENSE_LAYER_ACTIVATION, padding='same'),
    BatchNormalization(),
    AveragePooling2D(),
    Conv2D(128, kernel_size=(5, 5), activation=DENSE_LAYER_ACTIVATION, padding='same'),
    BatchNormalization(),
    AveragePooling2D(pool_size=(1, 1)),
    Flatten(),
    Dense(128, activation=DENSE_LAYER_ACTIVATION),
    Dropout(0.5),
    Dense(number_of_classes, activation=FINAL_LAYER_ACTIVATION)
])
#model.summary()

# %%
# 모델 컴파일
#LOSS_FUNCTION = 'categorical_crossentropy'
#LEARNING_RATE = 0.001
#METRICS = ['accuracy']

model.compile(optimizer=optimizer,
            loss=LOSS_FUNCTION,
            metrics=METRICS)

# 콜백 설정
#DECAY_FACTOR = 0.2
#PATIENCE = 3
#MIN_LEARNING_RATE = 0.0001

callbacks_balance = [
    ModelCheckpoint(CHECK_POINT_BALANCE, verbose=1, save_best_only=True, monitor='val_accuracy', mode='max'),
    EarlyStopping(monitor='val_accuracy', restore_best_weights=True, patience=PATIENCE, mode='max'),
    ReduceLROnPlateau(monitor='val_loss', patience=PATIENCE, factor=DECAY_FACTOR, min_lr=MIN_LEARNING_RATE)
]

# %%
start_time = time.time()  # 학습 시작 시간

# 모델 학습
history_balance = model.fit(train_x_balance, train_y_balance, batch_size=BATCH_SIZE, epochs=EPOCHS, 
                                validation_data=(val_x_balance, val_y_balance), callbacks=callbacks_balance)

training_time = time.time() - start_time
# Out:
# Epoch 1/100
# 1499/1499 [==============================] - ETA: 0s - loss: 2.5727 - accuracy: 0.3130
# Epoch 1: val_accuracy improved from -inf to 0.57547, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 10s 3ms/step - loss: 2.5727 - accuracy: 0.3130 - val_loss: 1.6850 - val_accuracy: 0.5755 - lr: 5.0000e-04
# Epoch 2/100
# 1484/1499 [============================>.] - ETA: 0s - loss: 1.9586 - accuracy: 0.4593
# Epoch 2: val_accuracy improved from 0.57547 to 0.62772, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.9565 - accuracy: 0.4599 - val_loss: 1.4281 - val_accuracy: 0.6277 - lr: 5.0000e-04
# Epoch 3/100
# 1496/1499 [============================>.] - ETA: 0s - loss: 1.7334 - accuracy: 0.5201
# Epoch 3: val_accuracy improved from 0.62772 to 0.66543, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.7331 - accuracy: 0.5202 - val_loss: 1.2612 - val_accuracy: 0.6654 - lr: 5.0000e-04
# Epoch 4/100
# 1479/1499 [============================>.] - ETA: 0s - loss: 1.5728 - accuracy: 0.5603
# Epoch 4: val_accuracy improved from 0.66543 to 0.67790, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 5s 3ms/step - loss: 1.5722 - accuracy: 0.5605 - val_loss: 1.1832 - val_accuracy: 0.6779 - lr: 5.0000e-04
# Epoch 5/100
# 1478/1499 [============================>.] - ETA: 0s - loss: 1.4388 - accuracy: 0.5923
# Epoch 5: val_accuracy improved from 0.67790 to 0.70721, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.4375 - accuracy: 0.5928 - val_loss: 1.0455 - val_accuracy: 0.7072 - lr: 5.0000e-04
# Epoch 6/100
# 1486/1499 [============================>.] - ETA: 0s - loss: 1.3304 - accuracy: 0.6213
# Epoch 6: val_accuracy improved from 0.70721 to 0.72920, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.3292 - accuracy: 0.6216 - val_loss: 0.9555 - val_accuracy: 0.7292 - lr: 5.0000e-04
# Epoch 7/100
# 1478/1499 [============================>.] - ETA: 0s - loss: 1.2336 - accuracy: 0.6447
# Epoch 7: val_accuracy improved from 0.72920 to 0.74249, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.2330 - accuracy: 0.6449 - val_loss: 0.8964 - val_accuracy: 0.7425 - lr: 5.0000e-04
# Epoch 8/100
# 1494/1499 [============================>.] - ETA: 0s - loss: 1.1547 - accuracy: 0.6657
# Epoch 8: val_accuracy improved from 0.74249 to 0.75112, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.1548 - accuracy: 0.6657 - val_loss: 0.8462 - val_accuracy: 0.7511 - lr: 5.0000e-04
# Epoch 9/100
# 1486/1499 [============================>.] - ETA: 0s - loss: 1.0860 - accuracy: 0.6826
# Epoch 9: val_accuracy improved from 0.75112 to 0.76348, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.0854 - accuracy: 0.6828 - val_loss: 0.8017 - val_accuracy: 0.7635 - lr: 5.0000e-04
# Epoch 10/100
# 1487/1499 [============================>.] - ETA: 0s - loss: 1.0257 - accuracy: 0.6974
# Epoch 10: val_accuracy improved from 0.76348 to 0.77199, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.0260 - accuracy: 0.6972 - val_loss: 0.7583 - val_accuracy: 0.7720 - lr: 5.0000e-04
# Epoch 11/100
# 1476/1499 [============================>.] - ETA: 0s - loss: 0.9748 - accuracy: 0.7103
# Epoch 11: val_accuracy improved from 0.77199 to 0.78670, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.9750 - accuracy: 0.7104 - val_loss: 0.7053 - val_accuracy: 0.7867 - lr: 5.0000e-04
# Epoch 12/100
# 1479/1499 [============================>.] - ETA: 0s - loss: 0.9350 - accuracy: 0.7199
# Epoch 12: val_accuracy improved from 0.78670 to 0.78842, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.9342 - accuracy: 0.7200 - val_loss: 0.6821 - val_accuracy: 0.7884 - lr: 5.0000e-04
# Epoch 13/100
# 1488/1499 [============================>.] - ETA: 0s - loss: 0.8980 - accuracy: 0.7302
# Epoch 13: val_accuracy improved from 0.78842 to 0.79515, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.8984 - accuracy: 0.7302 - val_loss: 0.6565 - val_accuracy: 0.7952 - lr: 5.0000e-04
# Epoch 14/100
# 1487/1499 [============================>.] - ETA: 0s - loss: 0.8652 - accuracy: 0.7382
# Epoch 14: val_accuracy did not improve from 0.79515
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.8655 - accuracy: 0.7380 - val_loss: 0.7728 - val_accuracy: 0.7596 - lr: 5.0000e-04
# Epoch 15/100
# 1487/1499 [============================>.] - ETA: 0s - loss: 0.8346 - accuracy: 0.7463
# Epoch 15: val_accuracy improved from 0.79515 to 0.80585, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.8342 - accuracy: 0.7465 - val_loss: 0.6127 - val_accuracy: 0.8059 - lr: 5.0000e-04
# Epoch 16/100
# 1473/1499 [============================>.] - ETA: 0s - loss: 0.8136 - accuracy: 0.7518
# Epoch 16: val_accuracy improved from 0.80585 to 0.80993, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.8130 - accuracy: 0.7521 - val_loss: 0.5974 - val_accuracy: 0.8099 - lr: 5.0000e-04
# Epoch 17/100
# 1488/1499 [============================>.] - ETA: 0s - loss: 0.7872 - accuracy: 0.7587
# Epoch 17: val_accuracy improved from 0.80993 to 0.81661, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.7873 - accuracy: 0.7587 - val_loss: 0.5778 - val_accuracy: 0.8166 - lr: 5.0000e-04
# Epoch 18/100
# 1486/1499 [============================>.] - ETA: 0s - loss: 0.7679 - accuracy: 0.7636
# Epoch 18: val_accuracy improved from 0.81661 to 0.81755, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.7678 - accuracy: 0.7636 - val_loss: 0.5673 - val_accuracy: 0.8176 - lr: 5.0000e-04
# Epoch 19/100
# 1482/1499 [============================>.] - ETA: 0s - loss: 0.7547 - accuracy: 0.7651
# Epoch 19: val_accuracy did not improve from 0.81755
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.7546 - accuracy: 0.7652 - val_loss: 0.5640 - val_accuracy: 0.8165 - lr: 5.0000e-04
# Epoch 20/100
# 1478/1499 [============================>.] - ETA: 0s - loss: 0.7324 - accuracy: 0.7728
# Epoch 20: val_accuracy improved from 0.81755 to 0.82382, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.7317 - accuracy: 0.7730 - val_loss: 0.5363 - val_accuracy: 0.8238 - lr: 5.0000e-04
# Epoch 21/100
# 1490/1499 [============================>.] - ETA: 0s - loss: 0.7223 - accuracy: 0.7770
# Epoch 21: val_accuracy improved from 0.82382 to 0.82955, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.7224 - accuracy: 0.7769 - val_loss: 0.5263 - val_accuracy: 0.8296 - lr: 5.0000e-04
# Epoch 22/100
# 1485/1499 [============================>.] - ETA: 0s - loss: 0.7080 - accuracy: 0.7793
# Epoch 22: val_accuracy did not improve from 0.82955
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.7081 - accuracy: 0.7794 - val_loss: 0.5462 - val_accuracy: 0.8185 - lr: 5.0000e-04
# Epoch 23/100
# 1493/1499 [============================>.] - ETA: 0s - loss: 0.6944 - accuracy: 0.7834
# Epoch 23: val_accuracy did not improve from 0.82955
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.6943 - accuracy: 0.7833 - val_loss: 0.5341 - val_accuracy: 0.8251 - lr: 5.0000e-04
# Epoch 24/100
# 1483/1499 [============================>.] - ETA: 0s - loss: 0.6845 - accuracy: 0.7845
# Epoch 24: val_accuracy did not improve from 0.82955
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.6841 - accuracy: 0.7846 - val_loss: 0.5486 - val_accuracy: 0.8221 - lr: 5.0000e-04
# Epoch 25/100
# 1499/1499 [==============================] - ETA: 0s - loss: 0.6744 - accuracy: 0.7882
# Epoch 25: val_accuracy did not improve from 0.82955
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.6744 - accuracy: 0.7882 - val_loss: 0.5278 - val_accuracy: 0.8239 - lr: 5.0000e-04
# Epoch 26/100
# 1481/1499 [============================>.] - ETA: 0s - loss: 0.6649 - accuracy: 0.7908
# Epoch 26: val_accuracy improved from 0.82955 to 0.83363, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.6644 - accuracy: 0.7910 - val_loss: 0.4961 - val_accuracy: 0.8336 - lr: 5.0000e-04
# Epoch 27/100
# 1494/1499 [============================>.] - ETA: 0s - loss: 0.6554 - accuracy: 0.7922
# Epoch 27: val_accuracy did not improve from 0.83363
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.6558 - accuracy: 0.7921 - val_loss: 0.5082 - val_accuracy: 0.8292 - lr: 5.0000e-04
# Epoch 28/100
# 1482/1499 [============================>.] - ETA: 0s - loss: 0.6444 - accuracy: 0.7967
# Epoch 28: val_accuracy improved from 0.83363 to 0.83800, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.6444 - accuracy: 0.7966 - val_loss: 0.4828 - val_accuracy: 0.8380 - lr: 5.0000e-04
# Epoch 29/100
# 1474/1499 [============================>.] - ETA: 0s - loss: 0.6383 - accuracy: 0.7972
# Epoch 29: val_accuracy did not improve from 0.83800
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.6379 - accuracy: 0.7972 - val_loss: 0.5061 - val_accuracy: 0.8301 - lr: 5.0000e-04
# Epoch 30/100
# 1483/1499 [============================>.] - ETA: 0s - loss: 0.6297 - accuracy: 0.8008
# Epoch 30: val_accuracy did not improve from 0.83800
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.6300 - accuracy: 0.8007 - val_loss: 0.4867 - val_accuracy: 0.8353 - lr: 5.0000e-04
# Epoch 31/100
# 1484/1499 [============================>.] - ETA: 0s - loss: 0.6224 - accuracy: 0.8009
# Epoch 31: val_accuracy improved from 0.83800 to 0.84368, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.6222 - accuracy: 0.8009 - val_loss: 0.4701 - val_accuracy: 0.8437 - lr: 5.0000e-04
# Epoch 32/100
# 1494/1499 [============================>.] - ETA: 0s - loss: 0.6148 - accuracy: 0.8044
# Epoch 32: val_accuracy did not improve from 0.84368
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.6146 - accuracy: 0.8045 - val_loss: 0.4878 - val_accuracy: 0.8366 - lr: 5.0000e-04
# Epoch 33/100
# 1490/1499 [============================>.] - ETA: 0s - loss: 0.6069 - accuracy: 0.8064
# Epoch 33: val_accuracy did not improve from 0.84368
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.6064 - accuracy: 0.8066 - val_loss: 0.4626 - val_accuracy: 0.8436 - lr: 5.0000e-04
# Epoch 34/100
# 1484/1499 [============================>.] - ETA: 0s - loss: 0.5998 - accuracy: 0.8083
# Epoch 34: val_accuracy did not improve from 0.84368
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.5997 - accuracy: 0.8083 - val_loss: 0.5104 - val_accuracy: 0.8316 - lr: 5.0000e-04
# Epoch 35/100
# 1476/1499 [============================>.] - ETA: 0s - loss: 0.5955 - accuracy: 0.8104
# Epoch 35: val_accuracy did not improve from 0.84368
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.5955 - accuracy: 0.8103 - val_loss: 0.4638 - val_accuracy: 0.8426 - lr: 5.0000e-04
# Epoch 36/100
# 1487/1499 [============================>.] - ETA: 0s - loss: 0.5918 - accuracy: 0.8112
# Epoch 36: val_accuracy improved from 0.84368 to 0.84486, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.5919 - accuracy: 0.8113 - val_loss: 0.4553 - val_accuracy: 0.8449 - lr: 5.0000e-04
# Epoch 37/100
# 1492/1499 [============================>.] - ETA: 0s - loss: 0.5826 - accuracy: 0.8133
# Epoch 37: val_accuracy did not improve from 0.84486
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.5825 - accuracy: 0.8132 - val_loss: 0.4760 - val_accuracy: 0.8395 - lr: 5.0000e-04
# Epoch 38/100
# 1488/1499 [============================>.] - ETA: 0s - loss: 0.5785 - accuracy: 0.8130
# Epoch 38: val_accuracy improved from 0.84486 to 0.84657, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.5779 - accuracy: 0.8131 - val_loss: 0.4509 - val_accuracy: 0.8466 - lr: 5.0000e-04
# Epoch 39/100
# 1475/1499 [============================>.] - ETA: 0s - loss: 0.5714 - accuracy: 0.8178
# Epoch 39: val_accuracy improved from 0.84657 to 0.84823, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.5722 - accuracy: 0.8173 - val_loss: 0.4587 - val_accuracy: 0.8482 - lr: 5.0000e-04
# Epoch 40/100
# 1488/1499 [============================>.] - ETA: 0s - loss: 0.5681 - accuracy: 0.8172
# Epoch 40: val_accuracy did not improve from 0.84823
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.5679 - accuracy: 0.8173 - val_loss: 0.4428 - val_accuracy: 0.8472 - lr: 5.0000e-04
# Epoch 41/100
# 1479/1499 [============================>.] - ETA: 0s - loss: 0.5611 - accuracy: 0.8199
# Epoch 41: val_accuracy did not improve from 0.84823
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.5605 - accuracy: 0.8201 - val_loss: 0.4547 - val_accuracy: 0.8456 - lr: 5.0000e-04
# Epoch 42/100
# 1499/1499 [==============================] - ETA: 0s - loss: 0.5599 - accuracy: 0.8181
# Epoch 42: val_accuracy improved from 0.84823 to 0.85047, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.5599 - accuracy: 0.8181 - val_loss: 0.4391 - val_accuracy: 0.8505 - lr: 5.0000e-04
# Epoch 43/100
# 1482/1499 [============================>.] - ETA: 0s - loss: 0.5566 - accuracy: 0.8191
# Epoch 43: val_accuracy did not improve from 0.85047
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.5562 - accuracy: 0.8192 - val_loss: 0.4398 - val_accuracy: 0.8489 - lr: 5.0000e-04
# Epoch 44/100
# 1472/1499 [============================>.] - ETA: 0s - loss: 0.5497 - accuracy: 0.8206
# Epoch 44: val_accuracy improved from 0.85047 to 0.85077, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.5501 - accuracy: 0.8206 - val_loss: 0.4334 - val_accuracy: 0.8508 - lr: 5.0000e-04
# Epoch 45/100
# 1487/1499 [============================>.] - ETA: 0s - loss: 0.5461 - accuracy: 0.8227
# Epoch 45: val_accuracy did not improve from 0.85077
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.5463 - accuracy: 0.8227 - val_loss: 0.4472 - val_accuracy: 0.8430 - lr: 5.0000e-04
# Epoch 46/100
# 1492/1499 [============================>.] - ETA: 0s - loss: 0.5402 - accuracy: 0.8250
# Epoch 46: val_accuracy did not improve from 0.85077
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.5400 - accuracy: 0.8251 - val_loss: 0.4407 - val_accuracy: 0.8484 - lr: 5.0000e-04
# Epoch 47/100
# 1496/1499 [============================>.] - ETA: 0s - loss: 0.5371 - accuracy: 0.8252
# Epoch 47: val_accuracy improved from 0.85077 to 0.85437, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.5370 - accuracy: 0.8252 - val_loss: 0.4281 - val_accuracy: 0.8544 - lr: 5.0000e-04
# Epoch 48/100
# 1477/1499 [============================>.] - ETA: 0s - loss: 0.5334 - accuracy: 0.8265
# Epoch 48: val_accuracy did not improve from 0.85437
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.5335 - accuracy: 0.8264 - val_loss: 0.4334 - val_accuracy: 0.8486 - lr: 5.0000e-04
# Epoch 49/100
# 1486/1499 [============================>.] - ETA: 0s - loss: 0.5293 - accuracy: 0.8267
# Epoch 49: val_accuracy did not improve from 0.85437
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.5290 - accuracy: 0.8268 - val_loss: 0.4481 - val_accuracy: 0.8482 - lr: 5.0000e-04
# Epoch 50/100
# 1483/1499 [============================>.] - ETA: 0s - loss: 0.5265 - accuracy: 0.8282
# Epoch 50: val_accuracy did not improve from 0.85437
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.5262 - accuracy: 0.8283 - val_loss: 0.4196 - val_accuracy: 0.8538 - lr: 5.0000e-04
# Epoch 51/100
# 1482/1499 [============================>.] - ETA: 0s - loss: 0.5250 - accuracy: 0.8292
# Epoch 51: val_accuracy did not improve from 0.85437
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.5249 - accuracy: 0.8291 - val_loss: 0.4203 - val_accuracy: 0.8536 - lr: 5.0000e-04
# Epoch 52/100
# 1494/1499 [============================>.] - ETA: 0s - loss: 0.5204 - accuracy: 0.8301
# Epoch 52: val_accuracy improved from 0.85437 to 0.85780, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.5204 - accuracy: 0.8302 - val_loss: 0.4101 - val_accuracy: 0.8578 - lr: 5.0000e-04
# Epoch 53/100
# 1473/1499 [============================>.] - ETA: 0s - loss: 0.5172 - accuracy: 0.8305
# Epoch 53: val_accuracy did not improve from 0.85780
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.5177 - accuracy: 0.8303 - val_loss: 0.4189 - val_accuracy: 0.8557 - lr: 5.0000e-04
# Epoch 54/100
# 1487/1499 [============================>.] - ETA: 0s - loss: 0.5138 - accuracy: 0.8322
# Epoch 54: val_accuracy did not improve from 0.85780
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.5139 - accuracy: 0.8322 - val_loss: 0.4881 - val_accuracy: 0.8383 - lr: 5.0000e-04
# Epoch 55/100
# 1487/1499 [============================>.] - ETA: 0s - loss: 0.5099 - accuracy: 0.8328
# Epoch 55: val_accuracy did not improve from 0.85780
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.5103 - accuracy: 0.8328 - val_loss: 0.4456 - val_accuracy: 0.8483 - lr: 5.0000e-04
# Epoch 56/100
# 1498/1499 [============================>.] - ETA: 0s - loss: 0.5077 - accuracy: 0.8340
# Epoch 56: val_accuracy improved from 0.85780 to 0.85904, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.5076 - accuracy: 0.8340 - val_loss: 0.4060 - val_accuracy: 0.8590 - lr: 5.0000e-04
# Epoch 57/100
# 1496/1499 [============================>.] - ETA: 0s - loss: 0.5028 - accuracy: 0.8350
# Epoch 57: val_accuracy did not improve from 0.85904
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.5029 - accuracy: 0.8349 - val_loss: 0.4265 - val_accuracy: 0.8504 - lr: 5.0000e-04
# Epoch 58/100
# 1477/1499 [============================>.] - ETA: 0s - loss: 0.4994 - accuracy: 0.8358
# Epoch 58: val_accuracy did not improve from 0.85904
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.4996 - accuracy: 0.8358 - val_loss: 0.4460 - val_accuracy: 0.8488 - lr: 5.0000e-04
# Epoch 59/100
# 1482/1499 [============================>.] - ETA: 0s - loss: 0.4981 - accuracy: 0.8368
# Epoch 59: val_accuracy improved from 0.85904 to 0.86034, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.4978 - accuracy: 0.8366 - val_loss: 0.4039 - val_accuracy: 0.8603 - lr: 5.0000e-04
# Epoch 60/100
# 1499/1499 [==============================] - ETA: 0s - loss: 0.4966 - accuracy: 0.8360
# Epoch 60: val_accuracy improved from 0.86034 to 0.86040, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.4966 - accuracy: 0.8360 - val_loss: 0.4038 - val_accuracy: 0.8604 - lr: 5.0000e-04
# Epoch 61/100
# 1492/1499 [============================>.] - ETA: 0s - loss: 0.4951 - accuracy: 0.8381
# Epoch 61: val_accuracy did not improve from 0.86040
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.4953 - accuracy: 0.8380 - val_loss: 0.4090 - val_accuracy: 0.8590 - lr: 5.0000e-04
# Epoch 62/100
# 1477/1499 [============================>.] - ETA: 0s - loss: 0.4922 - accuracy: 0.8397
# Epoch 62: val_accuracy did not improve from 0.86040
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.4922 - accuracy: 0.8397 - val_loss: 0.4040 - val_accuracy: 0.8585 - lr: 5.0000e-04
# Epoch 63/100
# 1484/1499 [============================>.] - ETA: 0s - loss: 0.4880 - accuracy: 0.8397
# Epoch 63: val_accuracy improved from 0.86040 to 0.86129, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.4880 - accuracy: 0.8397 - val_loss: 0.3965 - val_accuracy: 0.8613 - lr: 5.0000e-04
# Epoch 64/100
# 1490/1499 [============================>.] - ETA: 0s - loss: 0.4867 - accuracy: 0.8383
# Epoch 64: val_accuracy did not improve from 0.86129
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.4872 - accuracy: 0.8382 - val_loss: 0.4089 - val_accuracy: 0.8566 - lr: 5.0000e-04
# Epoch 65/100
# 1472/1499 [============================>.] - ETA: 0s - loss: 0.4835 - accuracy: 0.8416
# Epoch 65: val_accuracy did not improve from 0.86129
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.4832 - accuracy: 0.8417 - val_loss: 0.4073 - val_accuracy: 0.8581 - lr: 5.0000e-04
# Epoch 66/100
# 1475/1499 [============================>.] - ETA: 0s - loss: 0.4817 - accuracy: 0.8415
# Epoch 66: val_accuracy did not improve from 0.86129
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.4816 - accuracy: 0.8416 - val_loss: 0.3952 - val_accuracy: 0.8609 - lr: 5.0000e-04
# Epoch 67/100
# 1481/1499 [============================>.] - ETA: 0s - loss: 0.4804 - accuracy: 0.8406
# Epoch 67: val_accuracy improved from 0.86129 to 0.86312, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.4800 - accuracy: 0.8406 - val_loss: 0.3953 - val_accuracy: 0.8631 - lr: 5.0000e-04
# Epoch 68/100
# 1484/1499 [============================>.] - ETA: 0s - loss: 0.4741 - accuracy: 0.8436
# Epoch 68: val_accuracy did not improve from 0.86312
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.4744 - accuracy: 0.8435 - val_loss: 0.3910 - val_accuracy: 0.8615 - lr: 5.0000e-04
# Epoch 69/100
# 1494/1499 [============================>.] - ETA: 0s - loss: 0.4734 - accuracy: 0.8420
# Epoch 69: val_accuracy did not improve from 0.86312
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.4734 - accuracy: 0.8420 - val_loss: 0.3905 - val_accuracy: 0.8621 - lr: 5.0000e-04
# Epoch 70/100
# 1497/1499 [============================>.] - ETA: 0s - loss: 0.4714 - accuracy: 0.8440
# Epoch 70: val_accuracy improved from 0.86312 to 0.86478, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.4714 - accuracy: 0.8440 - val_loss: 0.3854 - val_accuracy: 0.8648 - lr: 5.0000e-04
# Epoch 71/100
# 1491/1499 [============================>.] - ETA: 0s - loss: 0.4684 - accuracy: 0.8443
# Epoch 71: val_accuracy did not improve from 0.86478
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.4680 - accuracy: 0.8445 - val_loss: 0.3845 - val_accuracy: 0.8629 - lr: 5.0000e-04
# Epoch 72/100
# 1495/1499 [============================>.] - ETA: 0s - loss: 0.4665 - accuracy: 0.8436
# Epoch 72: val_accuracy did not improve from 0.86478
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.4663 - accuracy: 0.8437 - val_loss: 0.3863 - val_accuracy: 0.8638 - lr: 5.0000e-04
# Epoch 73/100
# 1478/1499 [============================>.] - ETA: 0s - loss: 0.4652 - accuracy: 0.8454
# Epoch 73: val_accuracy did not improve from 0.86478
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.4642 - accuracy: 0.8456 - val_loss: 0.4378 - val_accuracy: 0.8498 - lr: 5.0000e-04
# Epoch 74/100
# 1480/1499 [============================>.] - ETA: 0s - loss: 0.4633 - accuracy: 0.8463
# Epoch 74: val_accuracy improved from 0.86478 to 0.86608, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.4633 - accuracy: 0.8463 - val_loss: 0.3833 - val_accuracy: 0.8661 - lr: 5.0000e-04
# Epoch 75/100
# 1494/1499 [============================>.] - ETA: 0s - loss: 0.4601 - accuracy: 0.8460
# Epoch 75: val_accuracy did not improve from 0.86608
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.4600 - accuracy: 0.8460 - val_loss: 0.4326 - val_accuracy: 0.8495 - lr: 5.0000e-04
# Epoch 76/100
# 1491/1499 [============================>.] - ETA: 0s - loss: 0.4561 - accuracy: 0.8476
# Epoch 76: val_accuracy did not improve from 0.86608
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.4557 - accuracy: 0.8477 - val_loss: 0.3915 - val_accuracy: 0.8596 - lr: 5.0000e-04
# Epoch 77/100
# 1476/1499 [============================>.] - ETA: 0s - loss: 0.4567 - accuracy: 0.8474
# Epoch 77: val_accuracy improved from 0.86608 to 0.86631, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.4565 - accuracy: 0.8473 - val_loss: 0.3850 - val_accuracy: 0.8663 - lr: 5.0000e-04
# Epoch 78/100
# 1488/1499 [============================>.] - ETA: 0s - loss: 0.4540 - accuracy: 0.8485
# Epoch 78: val_accuracy did not improve from 0.86631
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.4545 - accuracy: 0.8483 - val_loss: 0.3782 - val_accuracy: 0.8652 - lr: 5.0000e-04
# Epoch 79/100
# 1475/1499 [============================>.] - ETA: 0s - loss: 0.4528 - accuracy: 0.8493
# Epoch 79: val_accuracy did not improve from 0.86631
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.4531 - accuracy: 0.8494 - val_loss: 0.3988 - val_accuracy: 0.8606 - lr: 5.0000e-04
# Epoch 80/100
# 1479/1499 [============================>.] - ETA: 0s - loss: 0.4500 - accuracy: 0.8491
# Epoch 80: val_accuracy improved from 0.86631 to 0.86797, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.4508 - accuracy: 0.8489 - val_loss: 0.3746 - val_accuracy: 0.8680 - lr: 5.0000e-04
# Epoch 81/100
# 1480/1499 [============================>.] - ETA: 0s - loss: 0.4519 - accuracy: 0.8488
# Epoch 81: val_accuracy did not improve from 0.86797
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.4518 - accuracy: 0.8489 - val_loss: 0.3754 - val_accuracy: 0.8667 - lr: 5.0000e-04
# Epoch 82/100
# 1483/1499 [============================>.] - ETA: 0s - loss: 0.4489 - accuracy: 0.8501
# Epoch 82: val_accuracy improved from 0.86797 to 0.86826, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.4486 - accuracy: 0.8502 - val_loss: 0.3756 - val_accuracy: 0.8683 - lr: 5.0000e-04
# Epoch 83/100
# 1489/1499 [============================>.] - ETA: 0s - loss: 0.4467 - accuracy: 0.8493
# Epoch 83: val_accuracy did not improve from 0.86826
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.4469 - accuracy: 0.8492 - val_loss: 0.3746 - val_accuracy: 0.8682 - lr: 5.0000e-04
# Epoch 84/100
# 1474/1499 [============================>.] - ETA: 0s - loss: 0.4428 - accuracy: 0.8510
# Epoch 84: val_accuracy improved from 0.86826 to 0.86844, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.4433 - accuracy: 0.8509 - val_loss: 0.3717 - val_accuracy: 0.8684 - lr: 5.0000e-04
# Epoch 85/100
# 1478/1499 [============================>.] - ETA: 0s - loss: 0.4429 - accuracy: 0.8515
# Epoch 85: val_accuracy improved from 0.86844 to 0.86891, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.4425 - accuracy: 0.8518 - val_loss: 0.3722 - val_accuracy: 0.8689 - lr: 5.0000e-04
# Epoch 86/100
# 1491/1499 [============================>.] - ETA: 0s - loss: 0.4412 - accuracy: 0.8523
# Epoch 86: val_accuracy did not improve from 0.86891
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.4413 - accuracy: 0.8523 - val_loss: 0.3818 - val_accuracy: 0.8606 - lr: 5.0000e-04
# Epoch 87/100
# 1488/1499 [============================>.] - ETA: 0s - loss: 0.4407 - accuracy: 0.8520
# Epoch 87: val_accuracy improved from 0.86891 to 0.87074, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.4405 - accuracy: 0.8520 - val_loss: 0.3680 - val_accuracy: 0.8707 - lr: 5.0000e-04
# Epoch 88/100
# 1483/1499 [============================>.] - ETA: 0s - loss: 0.4382 - accuracy: 0.8537
# Epoch 88: val_accuracy did not improve from 0.87074
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.4385 - accuracy: 0.8535 - val_loss: 0.3908 - val_accuracy: 0.8598 - lr: 5.0000e-04
# Epoch 89/100
# 1491/1499 [============================>.] - ETA: 0s - loss: 0.4362 - accuracy: 0.8520
# Epoch 89: val_accuracy did not improve from 0.87074
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.4361 - accuracy: 0.8519 - val_loss: 0.3703 - val_accuracy: 0.8691 - lr: 5.0000e-04
# Epoch 90/100
# 1478/1499 [============================>.] - ETA: 0s - loss: 0.4355 - accuracy: 0.8534
# Epoch 90: val_accuracy did not improve from 0.87074
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.4357 - accuracy: 0.8532 - val_loss: 0.3672 - val_accuracy: 0.8691 - lr: 5.0000e-04
# Epoch 91/100
# 1497/1499 [============================>.] - ETA: 0s - loss: 0.4310 - accuracy: 0.8551
# Epoch 91: val_accuracy did not improve from 0.87074
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.4311 - accuracy: 0.8551 - val_loss: 0.3762 - val_accuracy: 0.8677 - lr: 5.0000e-04
# Epoch 92/100
# 1478/1499 [============================>.] - ETA: 0s - loss: 0.4287 - accuracy: 0.8547
# Epoch 92: val_accuracy did not improve from 0.87074
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.4299 - accuracy: 0.8545 - val_loss: 0.3729 - val_accuracy: 0.8665 - lr: 5.0000e-04
# Epoch 93/100
# 1494/1499 [============================>.] - ETA: 0s - loss: 0.4286 - accuracy: 0.8561
# Epoch 93: val_accuracy did not improve from 0.87074
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.4286 - accuracy: 0.8561 - val_loss: 0.3761 - val_accuracy: 0.8663 - lr: 5.0000e-04
# Epoch 94/100
# 1499/1499 [==============================] - ETA: 0s - loss: 0.4283 - accuracy: 0.8558
# Epoch 94: val_accuracy did not improve from 0.87074
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.4283 - accuracy: 0.8558 - val_loss: 0.3754 - val_accuracy: 0.8652 - lr: 5.0000e-04
# Epoch 95/100
# 1486/1499 [============================>.] - ETA: 0s - loss: 0.4268 - accuracy: 0.8562
# Epoch 95: val_accuracy improved from 0.87074 to 0.87270, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.4267 - accuracy: 0.8561 - val_loss: 0.3609 - val_accuracy: 0.8727 - lr: 5.0000e-04
# Epoch 96/100
# 1477/1499 [============================>.] - ETA: 0s - loss: 0.4250 - accuracy: 0.8581
# Epoch 96: val_accuracy did not improve from 0.87270
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.4255 - accuracy: 0.8581 - val_loss: 0.3988 - val_accuracy: 0.8588 - lr: 5.0000e-04
# Epoch 97/100
# 1477/1499 [============================>.] - ETA: 0s - loss: 0.4255 - accuracy: 0.8557
# Epoch 97: val_accuracy did not improve from 0.87270
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.4250 - accuracy: 0.8558 - val_loss: 0.3613 - val_accuracy: 0.8704 - lr: 5.0000e-04
# Epoch 98/100
# 1488/1499 [============================>.] - ETA: 0s - loss: 0.4227 - accuracy: 0.8564
# Epoch 98: val_accuracy did not improve from 0.87270
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.4228 - accuracy: 0.8564 - val_loss: 0.3695 - val_accuracy: 0.8706 - lr: 5.0000e-04
# Epoch 99/100
# 1498/1499 [============================>.] - ETA: 0s - loss: 0.4207 - accuracy: 0.8588
# Epoch 99: val_accuracy did not improve from 0.87270
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.4206 - accuracy: 0.8588 - val_loss: 0.3665 - val_accuracy: 0.8691 - lr: 5.0000e-04
# Epoch 100/100
# 1497/1499 [============================>.] - ETA: 0s - loss: 0.4197 - accuracy: 0.8584
# Epoch 100: val_accuracy did not improve from 0.87270
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.4196 - accuracy: 0.8584 - val_loss: 0.3587 - val_accuracy: 0.8720 - lr: 5.0000e-04

# %%
# 학습 결과 시각화
# Train 및 Validation Accuracy 데이터
train_accuracy = history_balance.history['accuracy']
val_accuracy = history_balance.history['val_accuracy']
train_loss = history_balance.history['loss']
val_loss = history_balance.history['val_loss']

# 그래프 생성
plt.figure(figsize=(10, 6))

# Train Accuracy 그래프
plt.plot(range(1, len(train_accuracy) + 1), train_accuracy, label='Train Accuracy')

# Validation Accuracy 그래프
plt.plot(range(1, len(val_accuracy) + 1), val_accuracy, label='Validation Accuracy')

plt.plot(range(1, len(train_accuracy) + 1), train_loss, label='Train Loss')

plt.plot(range(1, len(train_accuracy) + 1), val_loss, label='Validation Loss')
# 그래프 제목 및 축 레이블
plt.title('Model Accuracy with ResNet-34 (Training with bybalanced)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.ylim(0, 1)
plt.yticks(np.arange(0, 1.1, 0.05))

# 범례 추가
plt.legend()

# 그래프 출력
plt.show()

# %%
# Evaluate model
start_time = time.time()  # 추론 시작 시간
predictions = model.predict(test_x_balance)
end_time = time.time()  # 추론 종료 시간
total_inference_time = end_time - start_time
average_inference_time = total_inference_time / len(test_x_balance)

# 테스트 데이터에 대한 예측 결과 처리
predicted_classes = np.argmax(predictions, axis=1)
actual_classes = np.argmax(test_y_balance, axis=1)

# 정확도 계산
correct_predictions = np.sum(predicted_classes == actual_classes)
accuracy = correct_predictions / len(predicted_classes)

# 결과 출력
print(f"Correct Predictions: {correct_predictions}")
print(f"Total Predictions: {len(predicted_classes)}")
print(f"정확도: {accuracy:.4f}")
print(f"훈련시간 : {training_time:.2f} seconds.")
print(f"평균 추론 시간: {average_inference_time:.4f} seconds.") #각 샘플에 대한 추론 시간을 개별적으로 측정함으로써, 추론에 필요한 시간을 더 정확히 파악
# Out:
# Correct Predictions: 16344
# Total Predictions: 18799
# 정확도: 0.8694
# 훈련시간 : 401.15 seconds.
# 평균 추론 시간: 0.0000 seconds.

# %% [markdown]
# -------------------
