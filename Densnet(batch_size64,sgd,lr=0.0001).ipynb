# %% [markdown]
# ### `Basic setting`

# %%
import sys

assert sys.version_info >= (3, 7)

from packaging import version
import sklearn
print("sklearn version: ", sklearn.__version__)
assert version.parse(sklearn.__version__) >= version.parse("1.0.1")

import tensorflow as tf
print("TF version: ", tf.__version__)
assert version.parse(tf.__version__) >= version.parse("2.8.0")

import matplotlib.pyplot as plt

# Is this notebook running on Colab or Kaggle?
IS_COLAB = "google.colab" in sys.modules
IS_KAGGLE = "kaggle_secrets" in sys.modules

if not tf.config.list_physical_devices('GPU'):
    print("No GPU was detected. Neural nets can be very slow without a GPU.")
    if IS_COLAB:
        print("Go to Runtime > Change runtime and select a GPU hardware "
              "accelerator.")
    if IS_KAGGLE:
        print("Go to Settings > Accelerator and select GPU.")


# To prevent "CUDNN_STATUS_ALLOC_FAILED" error with GPUs
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# sklearn version:  1.0.2
# TF version:  2.8.0
# 1 Physical GPUs, 1 Logical GPUs

# %%
import os
import time
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Flatten, Dense, Dropout, BatchNormalization, LeakyReLU, ReLU, ELU
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD
np.random.seed(42)

# %%
# check GPU
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 11539525955014213867
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 9879683072
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 1988837882786811307
#  physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6"
#  xla_global_id: 416903419]

# %% [markdown]
# ### `Load dataset (by_merge)`

# %%
# Hyper parameter setting
BATCH_SIZE = 64
EPOCHS = 100
VALIDATION_SPLIT = 0.15
LEARNING_RATE = 0.0001
PATIENCE = 10
MIN_LEARNING_RATE = 0.0001
DECAY_FACTOR = 0.2
DENSE_LAYER_ACTIVATION = 'elu'
FINAL_LAYER_ACTIVATION = 'softmax'
LOSS_FUNCTION = 'categorical_crossentropy'
METRICS = ['accuracy']
optimizer = SGD(learning_rate=LEARNING_RATE)

CHECK_POINT_BALANCE = 'Best_points_densenet.h'

# %% [markdown]
# ### `Load dataset (by_balanced)`

# %%
# 데이터 불러오기
testing_set_balance = pd.read_csv('emnist-balanced-test.csv')
training_set_balance = pd.read_csv('emnist-balanced-train.csv')


# 훈련 데이터와 레이블 추출
train_y_balance = np.array(training_set_balance.iloc[:, 0].values)
train_x_balance = np.array(training_set_balance.iloc[:, 1:].values)

# 테스트 데이터와 레이블 추출
test_y_balance = np.array(testing_set_balance.iloc[:, 0].values)
test_x_balance = np.array(testing_set_balance.iloc[:, 1:].values)

# 데이터 정규화
train_x_balance = train_x_balance / 255.0
test_x_balance = test_x_balance / 255.0

# 이미지 크기 재조정 (데이터 차원 변경)
images_height = 28
images_width = 28
train_x_balance = train_x_balance.reshape(train_x_balance.shape[0], images_height, images_width, 1)
test_x_balance = test_x_balance.reshape(test_x_balance.shape[0], images_height, images_width, 1)

# 클래스 수 = 47
number_of_classes = 47

# 레이블 원-핫 인코딩
train_y_balance = tf.keras.utils.to_categorical(train_y_balance, number_of_classes)
test_y_balance = tf.keras.utils.to_categorical(test_y_balance, number_of_classes)

#VALIDATION_SPLIT = 0.15
train_x_balance, val_x_balance, train_y_balance, val_y_balance = train_test_split(train_x_balance, train_y_balance, 
                                                                              test_size=VALIDATION_SPLIT, random_state=42)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau,ModelCheckpoint
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Conv2D, Input,MaxPooling2D, Dense, Flatten ,Activation ,  BatchNormalization , Dropout ,AveragePooling2D
from tensorflow.keras.models import Model
from functools import partial

# %% [markdown]
# #### Training PersonalModelwith bybalanced dataset

# %%
# Define Densenet
model = tf.keras.Sequential([
    Conv2D(16, kernel_size=(5, 5), activation=DENSE_LAYER_ACTIVATION, input_shape=(28, 28, 1), padding='same'),
    AveragePooling2D(),
    # Conv2D(16, kernel_size=(3, 3), activation=DENSE_LAYER_ACTIVATION, padding='same'),
    # BatchNormalization(),
    # AveragePooling2D(),
    Conv2D(32, kernel_size=(5, 5), activation=DENSE_LAYER_ACTIVATION, padding='same'),
    BatchNormalization(),
    AveragePooling2D(),
    Conv2D(64, kernel_size=(5, 5), activation=DENSE_LAYER_ACTIVATION, padding='same'),
    BatchNormalization(),
    AveragePooling2D(),
    Conv2D(128, kernel_size=(5, 5), activation=DENSE_LAYER_ACTIVATION, padding='same'),
    BatchNormalization(),
    AveragePooling2D(pool_size=(1, 1)),
    Flatten(),
    Dense(128, activation=DENSE_LAYER_ACTIVATION),
    Dropout(0.5),
    Dense(number_of_classes, activation=FINAL_LAYER_ACTIVATION)
])
#model.summary()

# %%
# 모델 컴파일
#LOSS_FUNCTION = 'categorical_crossentropy'
#LEARNING_RATE = 0.001
#METRICS = ['accuracy']

model.compile(optimizer=optimizer,
            loss=LOSS_FUNCTION,
            metrics=METRICS)

# 콜백 설정
#DECAY_FACTOR = 0.2
#PATIENCE = 3
#MIN_LEARNING_RATE = 0.0001

callbacks_balance = [
    ModelCheckpoint(CHECK_POINT_BALANCE, verbose=1, save_best_only=True, monitor='val_accuracy', mode='max'),
    EarlyStopping(monitor='val_accuracy', restore_best_weights=True, patience=PATIENCE, mode='max'),
    ReduceLROnPlateau(monitor='val_loss', patience=PATIENCE, factor=DECAY_FACTOR, min_lr=MIN_LEARNING_RATE)
]

# %%
start_time = time.time()  # 학습 시작 시간

# 모델 학습
history_balance = model.fit(train_x_balance, train_y_balance, batch_size=BATCH_SIZE, epochs=EPOCHS, 
                                validation_data=(val_x_balance, val_y_balance), callbacks=callbacks_balance)

training_time = time.time() - start_time
# Out:
# Epoch 1/100
# 1499/1499 [==============================] - ETA: 0s - loss: 3.3778 - accuracy: 0.1476
# Epoch 1: val_accuracy improved from -inf to 0.40024, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 8s 3ms/step - loss: 3.3778 - accuracy: 0.1476 - val_loss: 2.4632 - val_accuracy: 0.4002 - lr: 1.0000e-04
# Epoch 2/100
# 1485/1499 [============================>.] - ETA: 0s - loss: 2.6210 - accuracy: 0.2939
# Epoch 2: val_accuracy improved from 0.40024 to 0.50502, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 2.6197 - accuracy: 0.2942 - val_loss: 2.0565 - val_accuracy: 0.5050 - lr: 1.0000e-04
# Epoch 3/100
# 1483/1499 [============================>.] - ETA: 0s - loss: 2.3481 - accuracy: 0.3637
# Epoch 3: val_accuracy improved from 0.50502 to 0.55242, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 2.3472 - accuracy: 0.3639 - val_loss: 1.8423 - val_accuracy: 0.5524 - lr: 1.0000e-04
# Epoch 4/100
# 1479/1499 [============================>.] - ETA: 0s - loss: 2.1953 - accuracy: 0.4004
# Epoch 4: val_accuracy improved from 0.55242 to 0.58008, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 2.1936 - accuracy: 0.4009 - val_loss: 1.7116 - val_accuracy: 0.5801 - lr: 1.0000e-04
# Epoch 5/100
# 1488/1499 [============================>.] - ETA: 0s - loss: 2.0838 - accuracy: 0.4291
# Epoch 5: val_accuracy improved from 0.58008 to 0.60112, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 2.0831 - accuracy: 0.4293 - val_loss: 1.6170 - val_accuracy: 0.6011 - lr: 1.0000e-04
# Epoch 6/100
# 1485/1499 [============================>.] - ETA: 0s - loss: 1.9971 - accuracy: 0.4496
# Epoch 6: val_accuracy improved from 0.60112 to 0.61300, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.9961 - accuracy: 0.4499 - val_loss: 1.5418 - val_accuracy: 0.6130 - lr: 1.0000e-04
# Epoch 7/100
# 1476/1499 [============================>.] - ETA: 0s - loss: 1.9309 - accuracy: 0.4681
# Epoch 7: val_accuracy improved from 0.61300 to 0.62914, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.9297 - accuracy: 0.4684 - val_loss: 1.4798 - val_accuracy: 0.6291 - lr: 1.0000e-04
# Epoch 8/100
# 1482/1499 [============================>.] - ETA: 0s - loss: 1.8708 - accuracy: 0.4846
# Epoch 8: val_accuracy improved from 0.62914 to 0.63812, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.8696 - accuracy: 0.4849 - val_loss: 1.4307 - val_accuracy: 0.6381 - lr: 1.0000e-04
# Epoch 9/100
# 1492/1499 [============================>.] - ETA: 0s - loss: 1.8124 - accuracy: 0.4977
# Epoch 9: val_accuracy improved from 0.63812 to 0.64835, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.8123 - accuracy: 0.4977 - val_loss: 1.3847 - val_accuracy: 0.6483 - lr: 1.0000e-04
# Epoch 10/100
# 1491/1499 [============================>.] - ETA: 0s - loss: 1.7642 - accuracy: 0.5112
# Epoch 10: val_accuracy improved from 0.64835 to 0.65597, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.7643 - accuracy: 0.5111 - val_loss: 1.3422 - val_accuracy: 0.6560 - lr: 1.0000e-04
# Epoch 11/100
# 1495/1499 [============================>.] - ETA: 0s - loss: 1.7185 - accuracy: 0.5227
# Epoch 11: val_accuracy improved from 0.65597 to 0.66655, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.7186 - accuracy: 0.5226 - val_loss: 1.3032 - val_accuracy: 0.6665 - lr: 1.0000e-04
# Epoch 12/100
# 1476/1499 [============================>.] - ETA: 0s - loss: 1.6760 - accuracy: 0.5350
# Epoch 12: val_accuracy improved from 0.66655 to 0.67358, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.6751 - accuracy: 0.5352 - val_loss: 1.2664 - val_accuracy: 0.6736 - lr: 1.0000e-04
# Epoch 13/100
# 1476/1499 [============================>.] - ETA: 0s - loss: 1.6364 - accuracy: 0.5453
# Epoch 13: val_accuracy improved from 0.67358 to 0.67985, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.6364 - accuracy: 0.5456 - val_loss: 1.2372 - val_accuracy: 0.6798 - lr: 1.0000e-04
# Epoch 14/100
# 1494/1499 [============================>.] - ETA: 0s - loss: 1.5962 - accuracy: 0.5547
# Epoch 14: val_accuracy improved from 0.67985 to 0.68534, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.5962 - accuracy: 0.5547 - val_loss: 1.2024 - val_accuracy: 0.6853 - lr: 1.0000e-04
# Epoch 15/100
# 1480/1499 [============================>.] - ETA: 0s - loss: 1.5640 - accuracy: 0.5627
# Epoch 15: val_accuracy improved from 0.68534 to 0.69043, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.5636 - accuracy: 0.5628 - val_loss: 1.1739 - val_accuracy: 0.6904 - lr: 1.0000e-04
# Epoch 16/100
# 1495/1499 [============================>.] - ETA: 0s - loss: 1.5339 - accuracy: 0.5706
# Epoch 16: val_accuracy improved from 0.69043 to 0.69675, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.5338 - accuracy: 0.5707 - val_loss: 1.1480 - val_accuracy: 0.6967 - lr: 1.0000e-04
# Epoch 17/100
# 1488/1499 [============================>.] - ETA: 0s - loss: 1.4972 - accuracy: 0.5805
# Epoch 17: val_accuracy improved from 0.69675 to 0.70148, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.4973 - accuracy: 0.5804 - val_loss: 1.1264 - val_accuracy: 0.7015 - lr: 1.0000e-04
# Epoch 18/100
# 1485/1499 [============================>.] - ETA: 0s - loss: 1.4688 - accuracy: 0.5876
# Epoch 18: val_accuracy improved from 0.70148 to 0.70715, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.4676 - accuracy: 0.5878 - val_loss: 1.0996 - val_accuracy: 0.7072 - lr: 1.0000e-04
# Epoch 19/100
# 1481/1499 [============================>.] - ETA: 0s - loss: 1.4344 - accuracy: 0.5956
# Epoch 19: val_accuracy improved from 0.70715 to 0.71229, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.4340 - accuracy: 0.5959 - val_loss: 1.0699 - val_accuracy: 0.7123 - lr: 1.0000e-04
# Epoch 20/100
# 1472/1499 [============================>.] - ETA: 0s - loss: 1.4079 - accuracy: 0.6028
# Epoch 20: val_accuracy improved from 0.71229 to 0.71814, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.4071 - accuracy: 0.6030 - val_loss: 1.0456 - val_accuracy: 0.7181 - lr: 1.0000e-04
# Epoch 21/100
# 1479/1499 [============================>.] - ETA: 0s - loss: 1.3764 - accuracy: 0.6108
# Epoch 21: val_accuracy improved from 0.71814 to 0.72264, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.3770 - accuracy: 0.6106 - val_loss: 1.0203 - val_accuracy: 0.7226 - lr: 1.0000e-04
# Epoch 22/100
# 1494/1499 [============================>.] - ETA: 0s - loss: 1.3561 - accuracy: 0.6185
# Epoch 22: val_accuracy improved from 0.72264 to 0.72719, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.3561 - accuracy: 0.6184 - val_loss: 1.0040 - val_accuracy: 0.7272 - lr: 1.0000e-04
# Epoch 23/100
# 1482/1499 [============================>.] - ETA: 0s - loss: 1.3243 - accuracy: 0.6226
# Epoch 23: val_accuracy improved from 0.72719 to 0.73067, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.3245 - accuracy: 0.6225 - val_loss: 0.9832 - val_accuracy: 0.7307 - lr: 1.0000e-04
# Epoch 24/100
# 1492/1499 [============================>.] - ETA: 0s - loss: 1.3028 - accuracy: 0.6298
# Epoch 24: val_accuracy improved from 0.73067 to 0.73304, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.3030 - accuracy: 0.6297 - val_loss: 0.9594 - val_accuracy: 0.7330 - lr: 1.0000e-04
# Epoch 25/100
# 1471/1499 [============================>.] - ETA: 0s - loss: 1.2859 - accuracy: 0.6319
# Epoch 25: val_accuracy did not improve from 0.73304
# 1499/1499 [==============================] - 4s 2ms/step - loss: 1.2858 - accuracy: 0.6318 - val_loss: 0.9676 - val_accuracy: 0.7323 - lr: 1.0000e-04
# Epoch 26/100
# 1482/1499 [============================>.] - ETA: 0s - loss: 1.2558 - accuracy: 0.6404
# Epoch 26: val_accuracy improved from 0.73304 to 0.74184, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.2566 - accuracy: 0.6402 - val_loss: 0.9283 - val_accuracy: 0.7418 - lr: 1.0000e-04
# Epoch 27/100
# 1497/1499 [============================>.] - ETA: 0s - loss: 1.2340 - accuracy: 0.6466
# Epoch 27: val_accuracy improved from 0.74184 to 0.74770, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.2342 - accuracy: 0.6466 - val_loss: 0.9052 - val_accuracy: 0.7477 - lr: 1.0000e-04
# Epoch 28/100
# 1498/1499 [============================>.] - ETA: 0s - loss: 1.2127 - accuracy: 0.6499
# Epoch 28: val_accuracy improved from 0.74770 to 0.74858, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.2128 - accuracy: 0.6499 - val_loss: 0.9000 - val_accuracy: 0.7486 - lr: 1.0000e-04
# Epoch 29/100
# 1482/1499 [============================>.] - ETA: 0s - loss: 1.1891 - accuracy: 0.6583
# Epoch 29: val_accuracy improved from 0.74858 to 0.75260, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.1887 - accuracy: 0.6585 - val_loss: 0.8791 - val_accuracy: 0.7526 - lr: 1.0000e-04
# Epoch 30/100
# 1490/1499 [============================>.] - ETA: 0s - loss: 1.1710 - accuracy: 0.6607
# Epoch 30: val_accuracy improved from 0.75260 to 0.76005, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.1706 - accuracy: 0.6609 - val_loss: 0.8505 - val_accuracy: 0.7600 - lr: 1.0000e-04
# Epoch 31/100
# 1485/1499 [============================>.] - ETA: 0s - loss: 1.1533 - accuracy: 0.6659
# Epoch 31: val_accuracy improved from 0.76005 to 0.76040, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.1534 - accuracy: 0.6659 - val_loss: 0.8434 - val_accuracy: 0.7604 - lr: 1.0000e-04
# Epoch 32/100
# 1480/1499 [============================>.] - ETA: 0s - loss: 1.1316 - accuracy: 0.6721
# Epoch 32: val_accuracy improved from 0.76040 to 0.76418, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.1307 - accuracy: 0.6722 - val_loss: 0.8317 - val_accuracy: 0.7642 - lr: 1.0000e-04
# Epoch 33/100
# 1494/1499 [============================>.] - ETA: 0s - loss: 1.1172 - accuracy: 0.6748
# Epoch 33: val_accuracy improved from 0.76418 to 0.76424, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.1176 - accuracy: 0.6747 - val_loss: 0.8173 - val_accuracy: 0.7642 - lr: 1.0000e-04
# Epoch 34/100
# 1478/1499 [============================>.] - ETA: 0s - loss: 1.0998 - accuracy: 0.6802
# Epoch 34: val_accuracy improved from 0.76424 to 0.76702, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.0997 - accuracy: 0.6801 - val_loss: 0.8017 - val_accuracy: 0.7670 - lr: 1.0000e-04
# Epoch 35/100
# 1473/1499 [============================>.] - ETA: 0s - loss: 1.0844 - accuracy: 0.6833
# Epoch 35: val_accuracy improved from 0.76702 to 0.77447, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.0846 - accuracy: 0.6830 - val_loss: 0.7879 - val_accuracy: 0.7745 - lr: 1.0000e-04
# Epoch 36/100
# 1499/1499 [==============================] - ETA: 0s - loss: 1.0672 - accuracy: 0.6886
# Epoch 36: val_accuracy improved from 0.77447 to 0.77524, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.0672 - accuracy: 0.6886 - val_loss: 0.7710 - val_accuracy: 0.7752 - lr: 1.0000e-04
# Epoch 37/100
# 1487/1499 [============================>.] - ETA: 0s - loss: 1.0537 - accuracy: 0.6913
# Epoch 37: val_accuracy improved from 0.77524 to 0.77931, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.0532 - accuracy: 0.6915 - val_loss: 0.7717 - val_accuracy: 0.7793 - lr: 1.0000e-04
# Epoch 38/100
# 1493/1499 [============================>.] - ETA: 0s - loss: 1.0406 - accuracy: 0.6946
# Epoch 38: val_accuracy improved from 0.77931 to 0.78280, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 5s 3ms/step - loss: 1.0406 - accuracy: 0.6946 - val_loss: 0.7616 - val_accuracy: 0.7828 - lr: 1.0000e-04
# Epoch 39/100
# 1496/1499 [============================>.] - ETA: 0s - loss: 1.0248 - accuracy: 0.6988
# Epoch 39: val_accuracy did not improve from 0.78280
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.0248 - accuracy: 0.6989 - val_loss: 0.7452 - val_accuracy: 0.7791 - lr: 1.0000e-04
# Epoch 40/100
# 1489/1499 [============================>.] - ETA: 0s - loss: 1.0112 - accuracy: 0.7034
# Epoch 40: val_accuracy did not improve from 0.78280
# 1499/1499 [==============================] - 4s 2ms/step - loss: 1.0109 - accuracy: 0.7034 - val_loss: 0.7363 - val_accuracy: 0.7819 - lr: 1.0000e-04
# Epoch 41/100
# 1498/1499 [============================>.] - ETA: 0s - loss: 1.0008 - accuracy: 0.7048
# Epoch 41: val_accuracy improved from 0.78280 to 0.78487, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 1.0008 - accuracy: 0.7047 - val_loss: 0.7236 - val_accuracy: 0.7849 - lr: 1.0000e-04
# Epoch 42/100
# 1487/1499 [============================>.] - ETA: 0s - loss: 0.9915 - accuracy: 0.7068
# Epoch 42: val_accuracy improved from 0.78487 to 0.78836, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.9914 - accuracy: 0.7068 - val_loss: 0.7157 - val_accuracy: 0.7884 - lr: 1.0000e-04
# Epoch 43/100
# 1493/1499 [============================>.] - ETA: 0s - loss: 0.9808 - accuracy: 0.7103
# Epoch 43: val_accuracy improved from 0.78836 to 0.79173, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.9809 - accuracy: 0.7102 - val_loss: 0.7071 - val_accuracy: 0.7917 - lr: 1.0000e-04
# Epoch 44/100
# 1476/1499 [============================>.] - ETA: 0s - loss: 0.9683 - accuracy: 0.7123
# Epoch 44: val_accuracy did not improve from 0.79173
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.9675 - accuracy: 0.7124 - val_loss: 0.6984 - val_accuracy: 0.7910 - lr: 1.0000e-04
# Epoch 45/100
# 1482/1499 [============================>.] - ETA: 0s - loss: 0.9561 - accuracy: 0.7149
# Epoch 45: val_accuracy improved from 0.79173 to 0.79344, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.9560 - accuracy: 0.7150 - val_loss: 0.7005 - val_accuracy: 0.7934 - lr: 1.0000e-04
# Epoch 46/100
# 1489/1499 [============================>.] - ETA: 0s - loss: 0.9466 - accuracy: 0.7194
# Epoch 46: val_accuracy improved from 0.79344 to 0.79675, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.9467 - accuracy: 0.7194 - val_loss: 0.6823 - val_accuracy: 0.7967 - lr: 1.0000e-04
# Epoch 47/100
# 1487/1499 [============================>.] - ETA: 0s - loss: 0.9358 - accuracy: 0.7211
# Epoch 47: val_accuracy did not improve from 0.79675
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.9354 - accuracy: 0.7212 - val_loss: 0.6839 - val_accuracy: 0.7926 - lr: 1.0000e-04
# Epoch 48/100
# 1494/1499 [============================>.] - ETA: 0s - loss: 0.9312 - accuracy: 0.7225
# Epoch 48: val_accuracy improved from 0.79675 to 0.79982, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.9310 - accuracy: 0.7226 - val_loss: 0.6703 - val_accuracy: 0.7998 - lr: 1.0000e-04
# Epoch 49/100
# 1479/1499 [============================>.] - ETA: 0s - loss: 0.9154 - accuracy: 0.7268
# Epoch 49: val_accuracy did not improve from 0.79982
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.9160 - accuracy: 0.7267 - val_loss: 0.6719 - val_accuracy: 0.7986 - lr: 1.0000e-04
# Epoch 50/100
# 1491/1499 [============================>.] - ETA: 0s - loss: 0.9090 - accuracy: 0.7270
# Epoch 50: val_accuracy improved from 0.79982 to 0.80142, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.9088 - accuracy: 0.7270 - val_loss: 0.6577 - val_accuracy: 0.8014 - lr: 1.0000e-04
# Epoch 51/100
# 1481/1499 [============================>.] - ETA: 0s - loss: 0.9012 - accuracy: 0.7298
# Epoch 51: val_accuracy did not improve from 0.80142
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.9010 - accuracy: 0.7298 - val_loss: 0.6557 - val_accuracy: 0.7982 - lr: 1.0000e-04
# Epoch 52/100
# 1478/1499 [============================>.] - ETA: 0s - loss: 0.8924 - accuracy: 0.7335
# Epoch 52: val_accuracy did not improve from 0.80142
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.8926 - accuracy: 0.7334 - val_loss: 0.6545 - val_accuracy: 0.8006 - lr: 1.0000e-04
# Epoch 53/100
# 1493/1499 [============================>.] - ETA: 0s - loss: 0.8815 - accuracy: 0.7361
# Epoch 53: val_accuracy improved from 0.80142 to 0.80496, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.8813 - accuracy: 0.7361 - val_loss: 0.6378 - val_accuracy: 0.8050 - lr: 1.0000e-04
# Epoch 54/100
# 1477/1499 [============================>.] - ETA: 0s - loss: 0.8785 - accuracy: 0.7351
# Epoch 54: val_accuracy did not improve from 0.80496
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.8786 - accuracy: 0.7351 - val_loss: 0.6403 - val_accuracy: 0.8008 - lr: 1.0000e-04
# Epoch 55/100
# 1498/1499 [============================>.] - ETA: 0s - loss: 0.8681 - accuracy: 0.7392
# Epoch 55: val_accuracy improved from 0.80496 to 0.80709, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.8681 - accuracy: 0.7392 - val_loss: 0.6286 - val_accuracy: 0.8071 - lr: 1.0000e-04
# Epoch 56/100
# 1489/1499 [============================>.] - ETA: 0s - loss: 0.8608 - accuracy: 0.7406
# Epoch 56: val_accuracy improved from 0.80709 to 0.80916, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.8609 - accuracy: 0.7405 - val_loss: 0.6321 - val_accuracy: 0.8092 - lr: 1.0000e-04
# Epoch 57/100
# 1493/1499 [============================>.] - ETA: 0s - loss: 0.8518 - accuracy: 0.7428
# Epoch 57: val_accuracy did not improve from 0.80916
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.8518 - accuracy: 0.7427 - val_loss: 0.6198 - val_accuracy: 0.8076 - lr: 1.0000e-04
# Epoch 58/100
# 1490/1499 [============================>.] - ETA: 0s - loss: 0.8471 - accuracy: 0.7448
# Epoch 58: val_accuracy did not improve from 0.80916
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.8473 - accuracy: 0.7448 - val_loss: 0.6394 - val_accuracy: 0.8020 - lr: 1.0000e-04
# Epoch 59/100
# 1498/1499 [============================>.] - ETA: 0s - loss: 0.8389 - accuracy: 0.7450
# Epoch 59: val_accuracy improved from 0.80916 to 0.81052, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.8389 - accuracy: 0.7450 - val_loss: 0.6088 - val_accuracy: 0.8105 - lr: 1.0000e-04
# Epoch 60/100
# 1483/1499 [============================>.] - ETA: 0s - loss: 0.8349 - accuracy: 0.7475
# Epoch 60: val_accuracy improved from 0.81052 to 0.81176, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.8352 - accuracy: 0.7474 - val_loss: 0.6055 - val_accuracy: 0.8118 - lr: 1.0000e-04
# Epoch 61/100
# 1499/1499 [==============================] - ETA: 0s - loss: 0.8281 - accuracy: 0.7491
# Epoch 61: val_accuracy did not improve from 0.81176
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.8281 - accuracy: 0.7491 - val_loss: 0.6055 - val_accuracy: 0.8116 - lr: 1.0000e-04
# Epoch 62/100
# 1493/1499 [============================>.] - ETA: 0s - loss: 0.8243 - accuracy: 0.7505
# Epoch 62: val_accuracy improved from 0.81176 to 0.81743, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.8243 - accuracy: 0.7506 - val_loss: 0.5952 - val_accuracy: 0.8174 - lr: 1.0000e-04
# Epoch 63/100
# 1483/1499 [============================>.] - ETA: 0s - loss: 0.8180 - accuracy: 0.7517
# Epoch 63: val_accuracy improved from 0.81743 to 0.81785, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.8177 - accuracy: 0.7519 - val_loss: 0.5947 - val_accuracy: 0.8178 - lr: 1.0000e-04
# Epoch 64/100
# 1494/1499 [============================>.] - ETA: 0s - loss: 0.8085 - accuracy: 0.7541
# Epoch 64: val_accuracy did not improve from 0.81785
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.8087 - accuracy: 0.7540 - val_loss: 0.6034 - val_accuracy: 0.8095 - lr: 1.0000e-04
# Epoch 65/100
# 1489/1499 [============================>.] - ETA: 0s - loss: 0.8047 - accuracy: 0.7559
# Epoch 65: val_accuracy did not improve from 0.81785
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.8044 - accuracy: 0.7559 - val_loss: 0.5867 - val_accuracy: 0.8168 - lr: 1.0000e-04
# Epoch 66/100
# 1496/1499 [============================>.] - ETA: 0s - loss: 0.8012 - accuracy: 0.7576
# Epoch 66: val_accuracy improved from 0.81785 to 0.81944, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.8011 - accuracy: 0.7576 - val_loss: 0.5829 - val_accuracy: 0.8194 - lr: 1.0000e-04
# Epoch 67/100
# 1480/1499 [============================>.] - ETA: 0s - loss: 0.7923 - accuracy: 0.7563
# Epoch 67: val_accuracy did not improve from 0.81944
# 1499/1499 [==============================] - 3s 2ms/step - loss: 0.7923 - accuracy: 0.7563 - val_loss: 0.6220 - val_accuracy: 0.8101 - lr: 1.0000e-04
# Epoch 68/100
# 1481/1499 [============================>.] - ETA: 0s - loss: 0.7876 - accuracy: 0.7588
# Epoch 68: val_accuracy improved from 0.81944 to 0.82145, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.7875 - accuracy: 0.7591 - val_loss: 0.5738 - val_accuracy: 0.8215 - lr: 1.0000e-04
# Epoch 69/100
# 1484/1499 [============================>.] - ETA: 0s - loss: 0.7832 - accuracy: 0.7621
# Epoch 69: val_accuracy did not improve from 0.82145
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.7834 - accuracy: 0.7621 - val_loss: 0.5740 - val_accuracy: 0.8195 - lr: 1.0000e-04
# Epoch 70/100
# 1470/1499 [============================>.] - ETA: 0s - loss: 0.7820 - accuracy: 0.7620
# Epoch 70: val_accuracy did not improve from 0.82145
# 1499/1499 [==============================] - 3s 2ms/step - loss: 0.7824 - accuracy: 0.7619 - val_loss: 0.5700 - val_accuracy: 0.8213 - lr: 1.0000e-04
# Epoch 71/100
# 1483/1499 [============================>.] - ETA: 0s - loss: 0.7736 - accuracy: 0.7636
# Epoch 71: val_accuracy did not improve from 0.82145
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.7729 - accuracy: 0.7637 - val_loss: 0.5751 - val_accuracy: 0.8172 - lr: 1.0000e-04
# Epoch 72/100
# 1499/1499 [==============================] - ETA: 0s - loss: 0.7682 - accuracy: 0.7651
# Epoch 72: val_accuracy did not improve from 0.82145
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.7682 - accuracy: 0.7651 - val_loss: 0.5775 - val_accuracy: 0.8190 - lr: 1.0000e-04
# Epoch 73/100
# 1487/1499 [============================>.] - ETA: 0s - loss: 0.7633 - accuracy: 0.7659
# Epoch 73: val_accuracy improved from 0.82145 to 0.82329, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.7630 - accuracy: 0.7660 - val_loss: 0.5596 - val_accuracy: 0.8233 - lr: 1.0000e-04
# Epoch 74/100
# 1480/1499 [============================>.] - ETA: 0s - loss: 0.7558 - accuracy: 0.7687
# Epoch 74: val_accuracy did not improve from 0.82329
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.7555 - accuracy: 0.7688 - val_loss: 0.5606 - val_accuracy: 0.8207 - lr: 1.0000e-04
# Epoch 75/100
# 1496/1499 [============================>.] - ETA: 0s - loss: 0.7555 - accuracy: 0.7679
# Epoch 75: val_accuracy improved from 0.82329 to 0.82340, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.7554 - accuracy: 0.7680 - val_loss: 0.5539 - val_accuracy: 0.8234 - lr: 1.0000e-04
# Epoch 76/100
# 1488/1499 [============================>.] - ETA: 0s - loss: 0.7507 - accuracy: 0.7693
# Epoch 76: val_accuracy did not improve from 0.82340
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.7506 - accuracy: 0.7694 - val_loss: 0.5570 - val_accuracy: 0.8225 - lr: 1.0000e-04
# Epoch 77/100
# 1488/1499 [============================>.] - ETA: 0s - loss: 0.7462 - accuracy: 0.7699
# Epoch 77: val_accuracy improved from 0.82340 to 0.82624, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.7463 - accuracy: 0.7697 - val_loss: 0.5517 - val_accuracy: 0.8262 - lr: 1.0000e-04
# Epoch 78/100
# 1487/1499 [============================>.] - ETA: 0s - loss: 0.7436 - accuracy: 0.7729
# Epoch 78: val_accuracy improved from 0.82624 to 0.82665, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.7439 - accuracy: 0.7729 - val_loss: 0.5448 - val_accuracy: 0.8267 - lr: 1.0000e-04
# Epoch 79/100
# 1479/1499 [============================>.] - ETA: 0s - loss: 0.7363 - accuracy: 0.7745
# Epoch 79: val_accuracy improved from 0.82665 to 0.82807, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.7362 - accuracy: 0.7745 - val_loss: 0.5458 - val_accuracy: 0.8281 - lr: 1.0000e-04
# Epoch 80/100
# 1480/1499 [============================>.] - ETA: 0s - loss: 0.7351 - accuracy: 0.7740
# Epoch 80: val_accuracy did not improve from 0.82807
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.7354 - accuracy: 0.7737 - val_loss: 0.5607 - val_accuracy: 0.8201 - lr: 1.0000e-04
# Epoch 81/100
# 1492/1499 [============================>.] - ETA: 0s - loss: 0.7298 - accuracy: 0.7755
# Epoch 81: val_accuracy did not improve from 0.82807
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.7298 - accuracy: 0.7755 - val_loss: 0.5455 - val_accuracy: 0.8245 - lr: 1.0000e-04
# Epoch 82/100
# 1494/1499 [============================>.] - ETA: 0s - loss: 0.7263 - accuracy: 0.7755
# Epoch 82: val_accuracy improved from 0.82807 to 0.83209, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.7261 - accuracy: 0.7755 - val_loss: 0.5331 - val_accuracy: 0.8321 - lr: 1.0000e-04
# Epoch 83/100
# 1474/1499 [============================>.] - ETA: 0s - loss: 0.7260 - accuracy: 0.7747
# Epoch 83: val_accuracy did not improve from 0.83209
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.7253 - accuracy: 0.7749 - val_loss: 0.5318 - val_accuracy: 0.8299 - lr: 1.0000e-04
# Epoch 84/100
# 1495/1499 [============================>.] - ETA: 0s - loss: 0.7206 - accuracy: 0.7778
# Epoch 84: val_accuracy did not improve from 0.83209
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.7205 - accuracy: 0.7778 - val_loss: 0.5348 - val_accuracy: 0.8262 - lr: 1.0000e-04
# Epoch 85/100
# 1490/1499 [============================>.] - ETA: 0s - loss: 0.7154 - accuracy: 0.7782
# Epoch 85: val_accuracy did not improve from 0.83209
# 1499/1499 [==============================] - 4s 2ms/step - loss: 0.7154 - accuracy: 0.7781 - val_loss: 0.5277 - val_accuracy: 0.8301 - lr: 1.0000e-04
# Epoch 86/100
# 1484/1499 [============================>.] - ETA: 0s - loss: 0.7134 - accuracy: 0.7804
# Epoch 86: val_accuracy did not improve from 0.83209
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.7134 - accuracy: 0.7804 - val_loss: 0.5322 - val_accuracy: 0.8304 - lr: 1.0000e-04
# Epoch 87/100
# 1490/1499 [============================>.] - ETA: 0s - loss: 0.7073 - accuracy: 0.7809
# Epoch 87: val_accuracy did not improve from 0.83209
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.7074 - accuracy: 0.7810 - val_loss: 0.5325 - val_accuracy: 0.8296 - lr: 1.0000e-04
# Epoch 88/100
# 1492/1499 [============================>.] - ETA: 0s - loss: 0.7055 - accuracy: 0.7799
# Epoch 88: val_accuracy did not improve from 0.83209
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.7057 - accuracy: 0.7798 - val_loss: 0.5335 - val_accuracy: 0.8290 - lr: 1.0000e-04
# Epoch 89/100
# 1483/1499 [============================>.] - ETA: 0s - loss: 0.7018 - accuracy: 0.7812
# Epoch 89: val_accuracy did not improve from 0.83209
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.7025 - accuracy: 0.7810 - val_loss: 0.5278 - val_accuracy: 0.8292 - lr: 1.0000e-04
# Epoch 90/100
# 1486/1499 [============================>.] - ETA: 0s - loss: 0.6988 - accuracy: 0.7844
# Epoch 90: val_accuracy did not improve from 0.83209
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.6982 - accuracy: 0.7846 - val_loss: 0.5960 - val_accuracy: 0.8069 - lr: 1.0000e-04
# Epoch 91/100
# 1475/1499 [============================>.] - ETA: 0s - loss: 0.6973 - accuracy: 0.7835
# Epoch 91: val_accuracy did not improve from 0.83209
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.6975 - accuracy: 0.7836 - val_loss: 0.5216 - val_accuracy: 0.8311 - lr: 1.0000e-04
# Epoch 92/100
# 1492/1499 [============================>.] - ETA: 0s - loss: 0.6923 - accuracy: 0.7848
# Epoch 92: val_accuracy improved from 0.83209 to 0.83558, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 5s 3ms/step - loss: 0.6925 - accuracy: 0.7846 - val_loss: 0.5137 - val_accuracy: 0.8356 - lr: 1.0000e-04
# Epoch 93/100
# 1490/1499 [============================>.] - ETA: 0s - loss: 0.6908 - accuracy: 0.7854
# Epoch 93: val_accuracy did not improve from 0.83558
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.6909 - accuracy: 0.7854 - val_loss: 0.5179 - val_accuracy: 0.8310 - lr: 1.0000e-04
# Epoch 94/100
# 1494/1499 [============================>.] - ETA: 0s - loss: 0.6919 - accuracy: 0.7848
# Epoch 94: val_accuracy did not improve from 0.83558
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.6919 - accuracy: 0.7849 - val_loss: 0.5085 - val_accuracy: 0.8348 - lr: 1.0000e-04
# Epoch 95/100
# 1499/1499 [==============================] - ETA: 0s - loss: 0.6821 - accuracy: 0.7865
# Epoch 95: val_accuracy improved from 0.83558 to 0.83641, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 5s 3ms/step - loss: 0.6821 - accuracy: 0.7865 - val_loss: 0.5063 - val_accuracy: 0.8364 - lr: 1.0000e-04
# Epoch 96/100
# 1477/1499 [============================>.] - ETA: 0s - loss: 0.6825 - accuracy: 0.7877
# Epoch 96: val_accuracy did not improve from 0.83641
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.6826 - accuracy: 0.7875 - val_loss: 0.5295 - val_accuracy: 0.8261 - lr: 1.0000e-04
# Epoch 97/100
# 1493/1499 [============================>.] - ETA: 0s - loss: 0.6805 - accuracy: 0.7875
# Epoch 97: val_accuracy did not improve from 0.83641
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.6806 - accuracy: 0.7875 - val_loss: 0.5044 - val_accuracy: 0.8350 - lr: 1.0000e-04
# Epoch 98/100
# 1499/1499 [==============================] - ETA: 0s - loss: 0.6821 - accuracy: 0.7879
# Epoch 98: val_accuracy did not improve from 0.83641
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.6821 - accuracy: 0.7879 - val_loss: 0.5099 - val_accuracy: 0.8361 - lr: 1.0000e-04
# Epoch 99/100
# 1499/1499 [==============================] - ETA: 0s - loss: 0.6725 - accuracy: 0.7898
# Epoch 99: val_accuracy improved from 0.83641 to 0.83729, saving model to Best_points_densenet.h
# INFO:tensorflow:Assets written to: Best_points_densenet.h\assets
# 1499/1499 [==============================] - 5s 3ms/step - loss: 0.6725 - accuracy: 0.7898 - val_loss: 0.5012 - val_accuracy: 0.8373 - lr: 1.0000e-04
# Epoch 100/100
# 1482/1499 [============================>.] - ETA: 0s - loss: 0.6707 - accuracy: 0.7905
# Epoch 100: val_accuracy did not improve from 0.83729
# 1499/1499 [==============================] - 4s 3ms/step - loss: 0.6711 - accuracy: 0.7905 - val_loss: 0.5020 - val_accuracy: 0.8352 - lr: 1.0000e-04

# %%
# 학습 결과 시각화
# Train 및 Validation Accuracy 데이터
train_accuracy = history_balance.history['accuracy']
val_accuracy = history_balance.history['val_accuracy']
train_loss = history_balance.history['loss']
val_loss = history_balance.history['val_loss']

# 그래프 생성
plt.figure(figsize=(10, 6))

# Train Accuracy 그래프
plt.plot(range(1, len(train_accuracy) + 1), train_accuracy, label='Train Accuracy')

# Validation Accuracy 그래프
plt.plot(range(1, len(val_accuracy) + 1), val_accuracy, label='Validation Accuracy')

plt.plot(range(1, len(train_accuracy) + 1), train_loss, label='Train Loss')

plt.plot(range(1, len(train_accuracy) + 1), val_loss, label='Validation Loss')
# 그래프 제목 및 축 레이블
plt.title('Model Accuracy with ResNet-34 (Training with bybalanced)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.ylim(0, 1)
plt.yticks(np.arange(0, 1.1, 0.05))

# 범례 추가
plt.legend()

# 그래프 출력
plt.show()

# %%
# Evaluate model
start_time = time.time()  # 추론 시작 시간
predictions = model.predict(test_x_balance)
end_time = time.time()  # 추론 종료 시간
total_inference_time = end_time - start_time
average_inference_time = total_inference_time / len(test_x_balance)

# 테스트 데이터에 대한 예측 결과 처리
predicted_classes = np.argmax(predictions, axis=1)
actual_classes = np.argmax(test_y_balance, axis=1)

# 정확도 계산
correct_predictions = np.sum(predicted_classes == actual_classes)
accuracy = correct_predictions / len(predicted_classes)

# 결과 출력
print(f"Correct Predictions: {correct_predictions}")
print(f"Total Predictions: {len(predicted_classes)}")
print(f"정확도: {accuracy:.4f}")
print(f"훈련시간 : {training_time:.2f} seconds.")
print(f"평균 추론 시간: {average_inference_time:.4f} seconds.") #각 샘플에 대한 추론 시간을 개별적으로 측정함으로써, 추론에 필요한 시간을 더 정확히 파악
# Out:
# Correct Predictions: 15656
# Total Predictions: 18799
# 정확도: 0.8328
# 훈련시간 : 409.43 seconds.
# 평균 추론 시간: 0.0000 seconds.

# %% [markdown]
# -------------------
